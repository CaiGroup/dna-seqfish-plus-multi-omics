# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/yujing/miniconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
data_path = "./intron_DE"
cell_type1 = "MLI1"
cell_type2 = "Purkinje"

# %%
df = pd.read_csv(os.path.join(data_path, 
                              "deg_deseq2_ensemble_{}_{}.txt".format(cell_type1, cell_type2)), 
                 sep = "\t").reset_index().rename(columns = {"index" : "gene"})
df
# Out:
#           gene    baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0        Psg19  453.987662        2.717450  0.224001  12.131410  7.199938e-34
# 1       Slc6a1   68.152806        4.208649  0.604273   6.964809  3.288506e-12
# 2      Galnt18   52.537974        7.114851  1.108422   6.418900  1.372624e-10
# 3      Fam107b   36.927508       -4.252455  0.675635  -6.294012  3.093643e-10
# 4        Grid2   92.325989       -2.227925  0.362797  -6.140977  8.201525e-10
# ...        ...         ...             ...       ...        ...           ...
# 17168   Zfp217    0.000000             NaN       NaN        NaN           NaN
# 17169    Zfp35    0.000000             NaN       NaN        NaN           NaN
# 17170  Zfp874a    0.000000             NaN       NaN        NaN           NaN
# 17171   Zfp956    0.000000             NaN       NaN        NaN           NaN
# 17172        a    0.000000             NaN       NaN        NaN           NaN
#
#                padj
# 0      1.227157e-29
# 1      2.802465e-08
# 2      7.798335e-07
# 3      1.318201e-06
# 4      2.795736e-06
# ...             ...
# 17168           NaN
# 17169           NaN
# 17170           NaN
# 17171           NaN
# 17172           NaN
#
# [17173 rows x 7 columns]

# %%
plt.scatter(df["log2FoldChange"], -np.log10(df["padj"]) , s = 2)

# %% [markdown]
# # use log fold change 2 / -2 as cuttoff

# %%
df[(df["padj"] < 0.01) & (df["log2FoldChange"] > 2)]
# Out:
#         gene    baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0      Psg19  453.987662        2.717450  0.224001  12.131410  7.199938e-34
# 1     Slc6a1   68.152806        4.208649  0.604273   6.964809  3.288506e-12
# 2    Galnt18   52.537974        7.114851  1.108422   6.418900  1.372624e-10
# 8      Myo16   38.919751        4.973649  0.864091   5.755934  8.616412e-09
# 9    Kirrel3   34.706832        6.298124  1.138005   5.534355  3.123749e-08
# 12     Asic2   25.729056        5.572366  1.035500   5.381330  7.393740e-08
# 15    Adarb2   22.746680        4.613180  0.889674   5.185245  2.157310e-07
# 20      Bcan   46.221746        2.632149  0.536555   4.905645  9.312077e-07
# 24    Sorcs3   20.657387        5.877827  1.210244   4.856730  1.193403e-06
# 29     Apba2   32.723882        5.252982  1.126522   4.663009  3.116185e-06
# 35    Inpp4b   26.635682        7.093631  1.557316   4.555036  5.237649e-06
# 38  Marchf11   16.817021        5.541634  1.248355   4.439148  9.031573e-06
# 53     Lsamp   13.998293        6.858735  1.646485   4.165683  3.104212e-05
#
#             padj
# 0   1.227157e-29
# 1   2.802465e-08
# 2   7.798335e-07
# 8   1.631757e-05
# 9   4.840107e-05
# 12  9.693762e-05
# 15  2.298075e-04
# 20  7.557859e-04
# 24  8.136141e-04
# 29  1.770409e-03
# 35  2.479736e-03
# 38  3.947029e-03
# 53  9.797814e-03

# %%
df[(df["padj"] < 0.01) & (df["log2FoldChange"] < -2
# 16  2.742959e-07  0.000275
# 17  5.335178e-07  0.000455
# 18  5.325574e-07  0.000455
# 19  4.879664e-07  0.000455
# 21  1.036857e-06  0.000803
# 22  1.093681e-06  0.000810
# 23  1.161634e-06  0.000814
# 25  1.327938e-06  0.000871
# 26  1.744328e-06  0.001101
# 27  1.919886e-06  0.001169
# 28  2.821830e-06  0.001658
# 30  3.285457e-06  0.001806
# 31  3.479957e-06  0.001854
# 32  4.140784e-06  0.002139
# 33  4.660221e-06  0.002336
# 34  4.909576e-06  0.002391
# 36  7.733211e-06  0.003562
# 37  8.352384e-06  0.003746
# 39  9.515604e-06  0.004055
# 40  1.056714e-05  0.004094
# 41  1.056978e-05  0.004094
# 42  1.020921e-05  0.004094
# 43  1.033074e-05  0.004094
# 44  1.239349e-05  0.004694
# 45  1.481554e-05  0.005437
# 46  1.499386e-05  0.005437
# 47  1.844695e-05  0.006550
# 48  1.893002e-05  0.006585
# 49  2.053231e-05  0.006999
# 50  2.161565e-05  0.007224
# 51  2.396761e-05  0.007856
# 52  2.604768e-05  0.008377
# 54  3.223076e-05  0.009988

# %% [markdown]
# # proceed with threshold 2 first

# %%
# check foldchange Granule cell marker gene
df[df["gene"].isin(["Lypd6", "Ppp1r17"])]
# fold change is calculated by granule / purkinje
# Out:
#          gene  baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# 151   Ppp1r17  6.027126       -6.241058  1.949689 -3.201053  0.001369
# 8999    Lypd6  4.437362        1.794919  1.736057  1.033906  0.301180
#
#           padj
# 151   0.153537
# 8999  1.000000

# %%
category = np.zeros(df.shape[0]).astype(object)
category[(df["padj"] < 0.01) & (df["log2FoldChange"] > 2)] = cell_type1
category[(df["padj"] < 0.01) & (df["log2FoldChange"] < -2)] = cell_type2

# %%
df["category"] = category
df.head()
# Out:
#       gene    baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0    Psg19  453.987662        2.717450  0.224001  12.131410  7.199938e-34
# 1   Slc6a1   68.152806        4.208649  0.604273   6.964809  3.288506e-12
# 2  Galnt18   52.537974        7.114851  1.108422   6.418900  1.372624e-10
# 3  Fam107b   36.927508       -4.252455  0.675635  -6.294012  3.093643e-10
# 4    Grid2   92.325989       -2.227925  0.362797  -6.140977  8.201525e-10
#
#            padj  category
# 0  1.227157e-29      MLI1
# 1  2.802465e-08      MLI1
# 2  7.798335e-07      MLI1
# 3  1.318201e-06  Purkinje
# 4  2.795736e-06  Purkinje

# %%
df[df["gene"].isin(["Lypd6", "Ppp1r17"])]
# Out:
#          gene  baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# 151   Ppp1r17  6.027126       -6.241058  1.949689 -3.201053  0.001369
# 8999    Lypd6  4.437362        1.794919  1.736057  1.033906  0.301180
#
#           padj category
# 151   0.153537      0.0
# 8999  1.000000      0.0

# %%
plt.scatter(df[df["category"] == cell_type1]["log2FoldChange"], -np.log10(df[df["category"] == cell_type1]["padj"]), label = cell_type1)
plt.scatter(df[df["category"] == cell_type2]["log2FoldChange"], -np.log10(df[df["category"] == cell_type2]["padj"]), label = cell_type2 )
plt.scatter(df[df["category"] == 0]["log2FoldChange"], -np.log10(df[df["category"] == 0]["padj"]), label = "non sig" )
# 44  1.239349e-05  4.694104e-03  Purkinje
# 45  1.481554e-05  5.437348e-03  Purkinje
# 46  1.499386e-05  5.437348e-03  Purkinje
# 47  1.844695e-05  6.550204e-03  Purkinje
# 48  1.893002e-05  6.584558e-03  Purkinje
# 49  2.053231e-05  6.999053e-03  Purkinje
# 50  2.161565e-05  7.223867e-03  Purkinje
# 51  2.396761e-05  7.855846e-03  Purkinje
# 52  2.604768e-05  8.376542e-03  Purkinje
# 53  3.104212e-05  9.797814e-03      MLI1
# 54  3.223076e-05  9.988019e-03  Purkinje

# %% [markdown]
# # Map back to genome

# %%
meta = pd.read_csv(os.path.join("../annot", "Final", "mm10_25kb_bins_genes_09022022.csv"))
meta = meta[["name", "chrom", "start", "end", "gene", "100kb name", "100kb bin", "200kb name", "200kb bin"]]
meta["gene"] = meta["gene"].str.replace("-", ".")
meta["gene"] = meta["gene"].str.replace("March", "Marchf")
meta["gene"] = meta["gene"].str.replace("Sept", "Septin")

# %% [markdown]
# # Mismatch between DE gene naming and annotated namming

# %%
DE_sig_25kb = meta.merge(DE_genes)

# %%
# missing genes
miss_genes = [x for x in DE_genes["gene"]  if x not in DE_sig_25kb["gene"].unique()]
print ("missing {} gene, {} of detected DE genes".format(len(miss_genes), len(miss_genes) / DE_genes.shape[0]) )

# missing gene are not trivial
miss_df = df[df["gene"].isin(miss_genes)]
miss_df
# Out:
# missing 1 gene, 0.01818181818181818 of detected DE genes
#               gene   baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# 31  X9530059O14Rik  14.691876       -7.549597  1.626982 -4.640245  0.000003
#
#         padj  category
# 31  0.001854  Purkinje

# %% [markdown]
# # OK! tried our best to get all genes

# %%
DE_sig_25kb["200kb bin"] = DE_sig_25kb["start"] // 200000
DE_sig_25kb["200kb name"] = DE_sig_25kb["chrom"] + "-g" + DE_sig_25kb["200kb bin"].astype(str)

# %%
cols = ["200kb name","chrom", "200kb bin", "gene", "baseMean", "log2FoldChange", "pvalue", "padj", "category"]

# %%
DE_sig_200kb = DE_sig_25kb.copy()
# Get DE norm counts
# Do not repeat count version
DE_sig_200kb_no_dup = DE_sig_200kb.drop_duplicates(subset=["gene", "200kb name"], keep='first')

# %%
DE_sig_200kb_no_dup
# Out:
#            name  chrom      start        end    gene  100kb name  100kb bin  \
# 0     chr1-3254   chr1   84350000   84375000    Dner   chr1-g843      843.0
# 2     chr1-3256   chr1   84400000   84425000    Dner   chr1-g844      844.0
# 10    chr1-3264   chr1   84600000   84625000    Dner   chr1-g846      846.0
# 14    chr1-4810   chr1  123325000  123350000   Dpp10  chr1-g1233     1233.0
# 17    chr1-4813   chr1  123400000  123425000   Dpp10  chr1-g1234     1234.0
# ..          ...    ...        ...        ...     ...         ...        ...
# 634   chr19-286  chr19   10225000   10250000   Dagla  chr19-g102      102.0
# 638  chr19-1805  chr19   48200000   48225000  Sorcs3  chr19-g482      482.0
# 646  chr19-1813  chr19   48400000   48425000  Sorcs3  chr19-g484      484.0
# 654  chr19-1821  chr19   48600000   48625000  Sorcs3  chr19-g486      486.0
# 662  chr19-1829  chr19   48800000   48825000  Sorcs3  chr19-g488      488.0
#
#      200kb name  200kb bin   baseMean  log2FoldChange     lfcSE      stat  \
# 0     chr1-g421        421  23.111086       -3.011954  0.716190 -4.205525
# 2     chr1-g422        422  23.111086       -3.011954  0.716190 -4.205525
# 10    chr1-g423        423  23.111086       -3.011954  0.716190 -4.205525
# 14    chr1-g616        616  22.665350       -4.637554  0.924885 -5.014196
# 17    chr1-g617        617  22.665350       -4.637554  0.924885 -5.014196
# ..          ...        ...        ...             ...       ...       ...
# 634   chr19-g51         51  22.500861       -4.696187  0.971184 -4.835526
# 638  chr19-g241        241  20.657387        5.877827  1.210244  4.856730
# 646  chr19-g242        242  20.657387        5.877827  1.210244  4.856730
# 654  chr19-g243        243  20.657387        5.877827  1.210244  4.856730
# 662  chr19-g244        244  20.657387        5.877827  1.210244  4.856730
#
#            pvalue      padj  category
# 0    2.604768e-05  0.008377  Purkinje
# 2    2.604768e-05  0.008377  Purkinje
# 10   2.604768e-05  0.008377  Purkinje
# 14   5.325574e-07  0.000455  Purkinje
# 17   5.325574e-07  0.000455  Purkinje
# ..            ...       ...       ...
# 634  1.327938e-06  0.000871  Purkinje
# 638  1.193403e-06  0.000814      MLI1
# 646  1.193403e-06  0.000814      MLI1
# 654  1.193403e-06  0.000814      MLI1
# 662  1.193403e-06  0.000814      MLI1
#
# [126 rows x 16 columns]

# %%
# get norm counts
norm_counts = pd.read_csv(os.path.join(data_path, 
                                       "ensembl_gene_counts_normalized.txt"), sep = "\t")

idx = (norm_counts.iloc[0].isin([cell_type1 ,cell_type2, "CLUSTER"])).values

norm_counts = norm_counts.iloc[:, idx]

# take a look
norm_counts.head()
# Out:
#                ID   1.2               2.2               1.3               2.3
# 0         CLUSTER  MLI1              MLI1          Purkinje          Purkinje
# 1  X0610005C13Rik     0  1.25478353316771                 0                 0
# 2  X0610009B22Rik     0                 0                 0  1.43733835690721
# 3  X0610009L18Rik     0                 0                 0  1.43733835690721
# 4  X0610010F05Rik     0                 0  1.30792047676341                 0

# %%
n1 = ["{}_{}".format(cell_type1, i) for i in range(1, 3)]
n2 = ["{}_{}".format(cell_type2, i) for i in range(1, 3)]

norm_counts.columns = ['gene'] + n1 + n2
norm_counts = norm_counts.iloc[1:].reset_index(drop = True)
norm_counts.head()
# turn dataframes to numeric
norm_counts[n1 + n2] = norm_counts[n1 + n2].apply(pd.to_numeric, errors='coerce')

# %%
norm_counts["{}_mean".format(cell_type1)] = norm_counts[n1].mean(axis=1)
norm_counts["{}_mean".format(cell_type2)] = norm_counts[n2].mean(axis=1)
norm_counts
# Out:
#                  gene   MLI1_1    MLI1_2  Purkinje_1  Purkinje_2  MLI1_mean  \
# 0      X0610009B22Rik  0.00000  0.000000    0.000000    1.437338   0.000000
# 1      X0610009L18Rik  0.00000  0.000000    0.000000    1.437338   0.000000
# 2      X0610010F05Rik  0.00000  0.000000    1.307920    0.000000   0.000000
# 3      X0610040B10Rik  0.00000  1.254784    1.307920    1.437338   0.627392
# 4      X0610040F04Rik  0.00000  1.254784    1.307920    0.000000   0.627392
# ...               ...      ...       ...         ...         ...        ...
# 17167             Zyx  4.55194  2.509567    0.000000    0.000000   3.530754
# 17168           Zzef1  0.00000  0.000000    1.307920    4.312015   0.000000
# 17169            Zzz3  2.27597  3.764351    5.231682    4.312015   3.020160
# 17170               a  0.00000  0.000000    0.000000    0.000000   0.000000
# 17171         ccdc198  0.00000  0.000000    0.000000    1.437338   0.000000
#
#        Purkinje_mean
# 0           0.718669
# 1           0.718669
# 2           0.653960
# 3           1.372629
# 4           0.653960
# ...              ...
# 17167       0.000000
# 17168       2.809968
# 17169       4.771848
# 17170       0.000000
# 17171       0.718669
#
# [17172 rows x 7 columns]

# %%
# filter out DE genes get norm counts
DE_sig_200kb_no_dup = DE_sig_200kb_no_dup.merge(norm_counts[["gene","{}_mean".format(cell_type1), "{}_mean".format(cell_type2)]])
DE_sig_200kb_no_dup.to_csv(os.path.join(data_path, "{}_{}_DE_sig_sum_200kb_no_dup.csv".format(cell_type1, cell_type2)), index = None)

# %%
DE_sig_200kb_no_dup
# Out:
#            name  chrom      start        end    gene  100kb name  100kb bin  \
# 0     chr1-3254   chr1   84350000   84375000    Dner   chr1-g843      843.0
# 1     chr1-3256   chr1   84400000   84425000    Dner   chr1-g844      844.0
# 2     chr1-3264   chr1   84600000   84625000    Dner   chr1-g846      846.0
# 3     chr1-4810   chr1  123325000  123350000   Dpp10  chr1-g1233     1233.0
# 4     chr1-4813   chr1  123400000  123425000   Dpp10  chr1-g1234     1234.0
# ..          ...    ...        ...        ...     ...         ...        ...
# 121   chr19-286  chr19   10225000   10250000   Dagla  chr19-g102      102.0
# 122  chr19-1805  chr19   48200000   48225000  Sorcs3  chr19-g482      482.0
# 123  chr19-1813  chr19   48400000   48425000  Sorcs3  chr19-g484      484.0
# 124  chr19-1821  chr19   48600000   48625000  Sorcs3  chr19-g486      486.0
# 125  chr19-1829  chr19   48800000   48825000  Sorcs3  chr19-g488      488.0
#
#      200kb name  200kb bin   baseMean  log2FoldChange     lfcSE      stat  \
# 0     chr1-g421        421  23.111086       -3.011954  0.716190 -4.205525
# 1     chr1-g422        422  23.111086       -3.011954  0.716190 -4.205525
# 2     chr1-g423        423  23.111086       -3.011954  0.716190 -4.205525
# 3     chr1-g616        616  22.665350       -4.637554  0.924885 -5.014196
# 4     chr1-g617        617  22.665350       -4.637554  0.924885 -5.014196
# ..          ...        ...        ...             ...       ...       ...
# 121   chr19-g51         51  22.500861       -4.696187  0.971184 -4.835526
# 122  chr19-g241        241  20.657387        5.877827  1.210244  4.856730
# 123  chr19-g242        242  20.657387        5.877827  1.210244  4.856730
# 124  chr19-g243        243  20.657387        5.877827  1.210244  4.856730
# 125  chr19-g244        244  20.657387        5.877827  1.210244  4.856730
#
#            pvalue      padj  category  MLI1_mean  Purkinje_mean
# 0    2.604768e-05  0.008377  Purkinje   9.687873      81.703805
# 1    2.604768e-05  0.008377  Purkinje   9.687873      81.703805
# 2    2.604768e-05  0.008377  Purkinje   9.687873      81.703805
# 3    5.325574e-07  0.000455  Purkinje   3.530754      82.163638
# 4    5.325574e-07  0.000455  Purkinje   3.530754      82.163638
# ..            ...       ...       ...        ...            ...
# 121  1.327938e-06  0.000871  Purkinje   3.530754      86.008949
# 122  1.193403e-06  0.000814      MLI1  80.960338       1.437338
# 123  1.193403e-06  0.000814      MLI1  80.960338       1.437338
# 124  1.193403e-06  0.000814      MLI1  80.960338       1.437338
# 125  1.193403e-06  0.000814      MLI1  80.960338       1.437338
#
# [126 rows x 18 columns]

# %%
temp = {"category" : ",".join, 
        "{}_mean".format(cell_type1) : sum,
        "{}_mean".format(cell_type2) : sum,
        "gene": ",".join}
final_200kb = DE_sig_200kb_no_dup.groupby("200kb name").agg(temp).reset_index()

# %%
# further format
final_200kb["chrom"]  = final_200kb["200kb name"].str.split("-").str[0]
# add small number to 0
final_200kb = final_200kb.replace(0, 0.05)
# rank final output
final_200kb["chrom_id"] = final_200kb["chrom"].str[3:].replace("X", 20).astype(int)
final_200kb["group"] = final_200kb["200kb name"].str.split("-").str[1].str[1:].astype(int)
final_200kb = final_200kb.sort_values(by = ["chrom_id", "group"])
final_200kb["log2FC_{}2{}".format(cell_type1[:1], cell_type2[:1])] =  np.log2(final_200kb["{}_mean".format(cell_type1)].values / final_200kb["{}_mean".format(cell_type2)].values)
final_200kb
# Out:
#     200kb name  category  MLI1_mean  Purkinje_mean    gene  chrom  chrom_id  \
# 0    chr1-g421  Purkinje   9.687873      81.703805    Dner   chr1         1
# 1    chr1-g422  Purkinje   9.687873      81.703805    Dner   chr1         1
# 2    chr1-g423  Purkinje   9.687873      81.703805    Dner   chr1         1
# 3    chr1-g616  Purkinje   3.530754      82.163638   Dpp10   chr1         1
# 4    chr1-g617  Purkinje   3.530754      82.163638   Dpp10   chr1         1
# ..         ...       ...        ...            ...     ...    ...       ...
# 62   chr19-g51  Purkinje   3.530754      86.008949   Dagla  chr19        19
# 58  chr19-g241      MLI1  80.960338       1.437338  Sorcs3  chr19        19
# 59  chr19-g242      MLI1  80.960338       1.437338  Sorcs3  chr19        19
# 60  chr19-g243      MLI1  80.960338       1.437338  Sorcs3  chr19        19
# 61  chr19-g244      MLI1  80.960338       1.437338  Sorcs3  chr19        19
#
#     group  log2FC_M2P
# 0     421   -3.076151
# 1     422   -3.076151
# 2     423   -3.076151
# 3     616   -4.540452
# 4     617   -4.540452
# ..    ...         ...
# 62     51   -4.606439
# 58    241    5.815744
# 59    242    5.815744
# 60    243    5.815744
# 61    244    5.815744
#
# [126 rows x 9 columns]

# %%
final_200kb.to_csv(os.path.join(data_path, "{}_{}_DE_200kb_FoldChange.csv".format(cell_type1, cell_type2)), index = False)
