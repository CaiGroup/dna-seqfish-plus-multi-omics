# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_path = "./intron_DE"
cell_type1 = "Bergmann"
cell_type2 = "MLI1"

# %%
df = pd.read_csv(os.path.join(data_path, 
                              "deg_deseq2_ensemble_{}_{}.txt".format(cell_type1, cell_type2)), 
                 sep = "\t").reset_index().rename(columns = {"index" : "gene"})
df.head()
# Out:
#       gene    baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 0  Septin4   85.370323        5.141679  0.547822  9.385679  6.251210e-21
# 1  Fam107a  104.456630        6.661803  0.739747  9.005518  2.146492e-19
# 2       Qk   57.442895        5.751206  0.765046  7.517461  5.585032e-14
# 3      Id4   56.763669        6.085603  0.831887  7.315423  2.565727e-13
# 4   Rsph3b   88.038382        3.041279  0.430754  7.060356  1.660764e-12
#
#            padj
# 0  5.369790e-18
# 1  9.219181e-17
# 2  1.599181e-11
# 3  5.509899e-11
# 4  2.853193e-10

# %%
plt.scatter(df["log2FoldChange"], -np.log10(df["padj"]) , s = 2)

# %% [markdown]
# # use log fold change 2 / -2 as cuttoff

# %%
df[(df["padj"] < 0.01) & (df["log2FoldChange"] > 2)]
# Out:
#         gene    baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 0    Septin4   85.370323        5.141679  0.547822  9.385679  6.251210e-21
# 1    Fam107a  104.456630        6.661803  0.739747  9.005518  2.146492e-19
# 2         Qk   57.442895        5.751206  0.765046  7.517461  5.585032e-14
# 3        Id4   56.763669        6.085603  0.831887  7.315423  2.565727e-13
# 4     Rsph3b   88.038382        3.041279  0.430754  7.060356  1.660764e-12
# ..       ...         ...             ...       ...       ...           ...
# 133    Gdf11    6.532205        5.768589  1.774621  3.250602  1.151608e-03
# 135    Ptprm   27.135889        3.217333  0.999528  3.218851  1.287053e-03
# 140  Hepacam    5.763078        6.214870  1.952759  3.182609  1.459546e-03
# 143    Nrcam   10.530896        4.342470  1.371153  3.167021  1.540091e-03
# 146   Cep85l    5.494583        5.816053  1.849136  3.145282  1.659266e-03
#
#              padj
# 0    5.369790e-18
# 1    9.219181e-17
# 2    1.599181e-11
# 3    5.509899e-11
# 4    2.853193e-10
# ..            ...
# 133  7.382320e-03
# 135  8.129256e-03
# 140  8.891844e-03
# 143  9.187070e-03
# 146  9.695985e-03
#
# [92 rows x 7 columns]

# %%
df[(df["padj"] < 0.01) & (df["log2FoldChange"] < -2)]
# Out:
#               gene   baseMean  log2FoldChange     lfcSE      stat  \
# 5           Snhg10  95.323981       -3.318758  0.477996 -6.943072
# 6          Galnt18  52.537974       -3.846395  0.559352 -6.876523
# 11         Kirrel3  34.706832       -4.346608  0.747747 -5.812939
# 20           Asic2  25.729056       -5.437595  1.040870 -5.224088
# 21           Trim9  52.116929       -3.622603  0.693128 -5.226458
# 22            Bcan  46.221746       -2.873676  0.556083 -5.167709
# 24          Sorcs3  20.657387       -8.158897  1.585368 -5.146375
# 25          Inpp4b  26.635682       -5.410204  1.056343 -5.121635
# 29          Snhg11  71.031788       -7.126074  1.441167 -4.944654
# 34          Adarb2  22.746680       -5.831676  1.203242 -4.846635
# 36          Kcnma1  37.095862       -7.394020  1.544281 -4.788003
# 42            Clmp  13.669562       -7.534215  1.633522 -4.612252
# 43            Sbk1  44.419414       -3.392479  0.745765 -4.548993
# 45         Pla2g4e  15.019670       -7.537543  1.678224 -4.491381
# 47           Pvalb  30.433991       -4.491935  1.009346 -4.450341
# 52             Tnr  17.910581       -4.388885  0.998433 -4.395773
# 56          Phyhip  27.761864       -3.563538  0.817882 -4.357032
# 57            Meg3  49.370985       -2.940023  0.679971 -4.323748
# 60        Marchf11  16.817021       -5.435054  1.263065 -4.303068
# 61         St8sia5  34.182321       -3.946371  0.916923 -4.303931
# 65            Hcn1  18.035440       -5.104800  1.218747 -4.188563
# 68            Ntn1  15.023947       -4.646636  1.112879 -4.175330
# 73          Atp1a3  25.560786       -4.280988  1.037629 -4.125740
# 77           Lrrn1  24.242866       -4.139382  1.018384 -4.064658
# 81          Clstn3  26.396881       -3.977054  1.008182 -3.944777
# 84           Pgbd5  37.518734       -3.160497  0.804161 -3.930182
# 86           Grik3  15.160870       -6.241413  1.603897 -3.891405
# 89           Gria3  13.330310       -6.335799  1.637004 -3.870362
# 91           Prkcg  16.524491       -6.239180  1.626174 -3.836723
# 93         C1qtnf4  18.409872       -3.858580  1.013622 -3.806723
# 99          Dusp15   9.426970       -6.413880  1.725850 -3.716359
# 102          Nptx1  41.760831       -3.505651  0.956564 -3.664835
# 107         Cacng2  15.043750       -5.797292  1.632461 -3.551258
# 108         Atp1b1  20.105014       -3.862233  1.093895 -3.530716
# 109         Cyfip2  18.594715       -3.782091  1.072103 -3.527732
# 112          Elmo1  17.998053       -4.768534  1.373390 -3.472091
# 114          Srrm4  23.161629       -5.351767  1.541141 -3.472601
# 115           Gad1  11.090321       -5.931386  1.715454 -3.457619
# 116         Shank2  23.232899       -4.060982  1.182386 -3.434564
# 118          Nceh1  10.361946       -5.875604  1.716648 -3.422719
# 123         Trim67  11.153100       -5.722339  1.695890 -3.374240
# 126          Phf24  13.774269       -2.997172  0.901769 -3.323657
# 128         Anks1b  10.310052       -5.693022  1.718872 -3.312069
# 130          Csmd1   5.940029       -6.246298  1.907590 -3.274445
# 134  A530058N18Rik   5.975396       -6.040266  1.876222 -3.219377
# 136         Sh3gl2  40.419966       -2.127139  0.663269 -3.207055
# 137          Frmd3   8.442385       -5.341724  1.671437 -3.195886
# 138        Gm14204  10.612457       -5.362730  1.677550 -3.196763
# 139         Kirrel   8.890615       -4.285656  1.342430 -3.192461
# 141           Lgi3  24.111137       -2.964320  0.933639 -3.175018
# 142          Coro6   8.178261       -5.332509  1.681089 -3.172057
# 144          Gfod1  21.505970       -5.048800  1.595325 -3.164746
# 145           Sncb  22.197801       -2.878530  0.911804 -3.156961
#
#            pvalue          padj
# 5    3.836646e-12  5.492798e-10
# 6    6.133121e-12  7.526215e-10
# 11   6.138531e-09  4.619478e-07
# 20   1.750153e-07  6.833554e-06
# 21   1.727878e-07  6.833554e-06
# 22   2.369804e-07  8.850702e-06
# 24   2.655688e-07  9.390083e-06
# 25   3.028975e-07  1.000727e-05
# 29   7.627937e-07  2.184132e-05
# 34   1.255733e-06  3.081927e-05
# 36   1.684494e-06  3.910758e-05
# 42   3.983299e-06  7.957334e-05
# 43   5.390324e-06  1.052338e-04
# 45   7.076286e-06  1.325936e-04
# 47   8.573418e-06  1.534285e-04
# 52   1.103792e-05  1.838742e-04
# 56   1.318380e-05  1.986822e-04
# 57   1.534003e-05  2.271912e-04
# 60   1.684490e-05  2.333834e-04
# 61   1.677939e-05  2.333834e-04
# 65   2.807259e-05  3.599158e-04
# 68   2.975541e-05  3.661560e-04
# 73   3.695440e-05  4.289706e-04
# 77   4.810303e-05  5.297501e-04
# 81   7.987417e-05  8.318856e-04
# 84   8.488153e-05  8.578028e-04
# 86   9.966558e-05  9.840544e-04
# 89   1.086738e-04  1.037231e-03
# 91   1.246871e-04  1.164198e-03
# 93   1.408203e-04  1.286858e-03
# 99   2.021140e-04  1.736159e-03
# 102  2.474983e-04  2.064088e-03
# 107  3.833942e-04  3.049404e-03
# 108  4.144365e-04  3.243584e-03
# 109  4.191360e-04  3.243584e-03
# 112  5.164208e-04  3.857439e-03
# 114  5.154410e-04  3.857439e-03
# 115  5.449719e-04  4.035611e-03
# 116  5.935086e-04  4.357469e-03
# 118  6.199807e-04  4.475323e-03
# 123  7.401975e-04  5.127659e-03
# 126  8.884552e-04  6.009315e-03
# 128  9.260871e-04  6.166735e-03
# 130  1.058698e-03  6.889557e-03
# 134  1.284697e-03  8.129256e-03
# 136  1.341015e-03  8.408262e-03
# 137  1.394020e-03  8.614843e-03
# 138  1.389790e-03  8.614843e-03
# 139  1.410658e-03  8.655393e-03
# 141  1.498270e-03  9.063479e-03
# 142  1.513632e-03  9.092380e-03
# 144  1.552182e-03  9.195337e-03
# 145  1.594229e-03  9.379742e-03

# %% [markdown]
# # proceed with threshold 2 first

# %%
# check foldchange Granule cell marker gene
df[df["gene"].isin(["Lypd6", "Gdf10"])]
# fold change is calculated by Bergmann / MLI1
# Out:
#        gene   baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 26    Gdf10  34.674536        7.354191  1.460191  5.036457  4.742278e-07
# 9363  Lypd6   4.437362       -1.524585  1.723084 -0.884800  3.762644e-01
#
#           padj
# 26    0.000015
# 9363       NaN

# %%
category = np.zeros(df.shape[0]).astype(object)
category[(df["padj"] < 0.01) & (df["log2FoldChange"] > 2)] = cell_type1
category[(df["padj"] < 0.01) & (df["log2FoldChange"] < -2)] = cell_type2

# %%
df["category"] = category
df.head()
# Out:
#       gene    baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 0  Septin4   85.370323        5.141679  0.547822  9.385679  6.251210e-21
# 1  Fam107a  104.456630        6.661803  0.739747  9.005518  2.146492e-19
# 2       Qk   57.442895        5.751206  0.765046  7.517461  5.585032e-14
# 3      Id4   56.763669        6.085603  0.831887  7.315423  2.565727e-13
# 4   Rsph3b   88.038382        3.041279  0.430754  7.060356  1.660764e-12
#
#            padj  category
# 0  5.369790e-18  Bergmann
# 1  9.219181e-17  Bergmann
# 2  1.599181e-11  Bergmann
# 3  5.509899e-11  Bergmann
# 4  2.853193e-10  Bergmann

# %%
df[df["gene"].isin(["Lypd6","Gdf10"])]
# Out:
#        gene   baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 26    Gdf10  34.674536        7.354191  1.460191  5.036457  4.742278e-07
# 9363  Lypd6   4.437362       -1.524585  1.723084 -0.884800  3.762644e-01
#
#           padj  category
# 26    0.000015  Bergmann
# 9363       NaN       0.0

# %%
plt.scatter(df[df["category"] == cell_type1]["log2FoldChange"], -np.log10(df[df["category"] == cell_type1]["padj"]), label = cell_type1)
plt.scatter(df[df["category"] == cell_type2]["log2FoldChange"], -np.log10(df[df["category"] == cell_type2]["padj"]), label = cell_type2 )
plt.scatter(df[df["category"] == 0]["log2FoldChange"], -np.log10(df[df["category"] == 0]["padj"]), label = "non sig" )
plt.legend()

# %%
DE_genes = df[df["category"] != 0]
DE_genes
# Out:
#         gene    baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 0    Septin4   85.370323        5.141679  0.547822  9.385679  6.251210e-21
# 1    Fam107a  104.456630        6.661803  0.739747  9.005518  2.146492e-19
# 2         Qk   57.442895        5.751206  0.765046  7.517461  5.585032e-14
# 3        Id4   56.763669        6.085603  0.831887  7.315423  2.565727e-13
# 4     Rsph3b   88.038382        3.041279  0.430754  7.060356  1.660764e-12
# ..       ...         ...             ...       ...       ...           ...
# 142    Coro6    8.178261       -5.332509  1.681089 -3.172057  1.513632e-03
# 143    Nrcam   10.530896        4.342470  1.371153  3.167021  1.540091e-03
# 144    Gfod1   21.505970       -5.048800  1.595325 -3.164746  1.552182e-03
# 145     Sncb   22.197801       -2.878530  0.911804 -3.156961  1.594229e-03
# 146   Cep85l    5.494583        5.816053  1.849136  3.145282  1.659266e-03
#
#              padj  category
# 0    5.369790e-18  Bergmann
# 1    9.219181e-17  Bergmann
# 2    1.599181e-11  Bergmann
# 3    5.509899e-11  Bergmann
# 4    2.853193e-10  Bergmann
# ..            ...       ...
# 142  9.092380e-03      MLI1
# 143  9.187070e-03  Bergmann
# 144  9.195337e-03      MLI1
# 145  9.379742e-03      MLI1
# 146  9.695985e-03  Bergmann
#
# [145 rows x 8 columns]

# %% [markdown]
# # Map back to genome

# %%
meta = pd.read_csv(os.path.join("../annot", "Final", "mm10_25kb_bins_genes_09022022.csv"))
meta = meta[["name", "chrom", "start", "end", "gene", "100kb name", "100kb bin", "200kb name", "200kb bin"]]
meta["gene"] = meta["gene"].str.replace("-", ".")
meta["gene"] = meta["gene"].str.replace("March", "Marchf")
meta["gene"] = meta["gene"].str.replace("Sept", "Septin")

# %% [markdown]
# # Mismatch between DE gene naming and annotated namming

# %%
DE_sig_25kb = meta.merge(DE_genes)

# %%
# missing genes
miss_genes = [x for x in DE_genes["gene"]  if x not in DE_sig_25kb["gene"].unique()]
print ("missing {} gene, {} of detected DE genes".format(len(miss_genes), len(miss_genes) / DE_genes.shape[0]) )

# missing gene are not trivial
miss_df = df[df["gene"].isin(miss_genes)]
miss_df
# Out:
# missing 2 gene, 0.013793103448275862 of detected DE genes
#                gene   baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# 97   X9330188P03Rik  12.462777        5.842664  1.552103  3.764352  0.000167
# 120  X2610035D17Rik  10.438414        4.489390  1.316020  3.411338  0.000646
#
#          padj  category
# 97   0.001464  Bergmann
# 120  0.004561  Bergmann

# %% [markdown]
# # OK! tried our best to get all genes
# format the last search to 200kb resolution

# %%
DE_sig_25kb["200kb bin"] = DE_sig_25kb["start"] // 200000
DE_sig_25kb["200kb name"] = DE_sig_25kb["chrom"] + "-g" + DE_sig_25kb["200kb bin"].astype(str)

# %%
cols = ["200kb name","chrom", "200kb bin", "gene", "baseMean", "log2FoldChange", "pvalue", "padj", "category"]

# %%
DE_sig_200kb = DE_sig_25kb.copy()
DE_sig_200kb
# Out:
#            name chrom      start        end   gene  100kb name  100kb bin  \
# 0     chr1-4067  chr1  104750000  104775000  Cdh20  chr1-g1047     1047.0
# 1     chr1-4068  chr1  104775000  104800000  Cdh20  chr1-g1047     1047.0
# 2     chr1-4069  chr1  104800000  104825000  Cdh20  chr1-g1048     1048.0
# 3     chr1-4070  chr1  104825000  104850000  Cdh20  chr1-g1048     1048.0
# 4     chr1-4071  chr1  104850000  104875000  Cdh20  chr1-g1048     1048.0
# ...         ...   ...        ...        ...    ...         ...        ...
# 1021  chrX-1469  chrX   41575000   41600000  Gria3   chrX-g415      415.0
# 1022  chrX-1470  chrX   41600000   41625000  Gria3   chrX-g416      416.0
# 1023  chrX-1471  chrX   41625000   41650000  Gria3   chrX-g416      416.0
# 1024  chrX-1472  chrX   41650000   41675000  Gria3   chrX-g416      416.0
# 1025  chrX-1473  chrX   41675000   41700000  Gria3   chrX-g416      416.0
#
#      200kb name  200kb bin   baseMean  log2FoldChange     lfcSE      stat  \
# 0     chr1-g523        523  25.158924        5.948869  1.212070  4.908025
# 1     chr1-g523        523  25.158924        5.948869  1.212070  4.908025
# 2     chr1-g524        524  25.158924        5.948869  1.212070  4.908025
# 3     chr1-g524        524  25.158924        5.948869  1.212070  4.908025
# 4     chr1-g524        524  25.158924        5.948869  1.212070  4.908025
# ...         ...        ...        ...             ...       ...       ...
# 1021  chrX-g207        207  13.330310       -6.335799  1.637004 -3.870362
# 1022  chrX-g208        208  13.330310       -6.335799  1.637004 -3.870362
# 1023  chrX-g208        208  13.330310       -6.335799  1.637004 -3.870362
# 1024  chrX-g208        208  13.330310       -6.335799  1.637004 -3.870362
# 1025  chrX-g208        208  13.330310       -6.335799  1.637004 -3.870362
#
#             pvalue      padj  category
# 0     9.199824e-07  0.000025  Bergmann
# 1     9.199824e-07  0.000025  Bergmann
# 2     9.199824e-07  0.000025  Bergmann
# 3     9.199824e-07  0.000025  Bergmann
# 4     9.199824e-07  0.000025  Bergmann
# ...            ...       ...       ...
# 1021  1.086738e-04  0.001037      MLI1
# 1022  1.086738e-04  0.001037      MLI1
# 1023  1.086738e-04  0.001037      MLI1
# 1024  1.086738e-04  0.001037      MLI1
# 1025  1.086738e-04  0.001037      MLI1
#
# [1026 rows x 16 columns]

# %%
# Get DE norm counts
# Do not repeat count version
DE_sig_200kb_no_dup = DE_sig_200kb.drop_duplicates(subset=["gene", "200kb name"], keep='first')

# %%
# get norm counts
norm_counts = pd.read_csv(os.path.join(data_path,
            "ensembl_gene_counts_normalized.txt"), sep = "\t")

idx = (norm_counts.iloc[0].isin([cell_type1 ,cell_type2, "CLUSTER"])).values

norm_counts = norm_counts.iloc[:, idx]

# take a look
norm_counts.head()
# Out:
#                ID         1                 2   1.2               2.2
# 0         CLUSTER  Bergmann          Bergmann  MLI1              MLI1
# 1  X0610005C13Rik         0  1.28156580039671     0  1.25478353316771
# 2  X0610009B22Rik         0                 0     0                 0
# 3  X0610009L18Rik         0                 0     0                 0
# 4  X0610010F05Rik         0                 0     0                 0

# %%
n1 = ["{}_{}".format(cell_type1, i) for i in range(1, 3)]
n2 = ["{}_{}".format(cell_type2, i) for i in range(1, 3)]

norm_counts.columns = ['gene'] + n1 + n2
norm_counts = norm_counts.iloc[1:].reset_index(drop = True)
norm_counts.head()
# turn dataframes to numeric
norm_counts[n1 + n2] = norm_counts[n1 + n2].apply(pd.to_numeric, errors='coerce')
norm_counts["{}_mean".format(cell_type1)] = norm_counts[n1].mean(axis=1)
norm_counts["{}_mean".format(cell_type2)] = norm_counts[n2].mean(axis=1)
norm_counts
# Out:
#                  gene  Bergmann_1  Bergmann_2   MLI1_1    MLI1_2  \
# 0      X0610005C13Rik    0.000000    1.281566  0.00000  1.254784
# 1      X0610009B22Rik    0.000000    0.000000  0.00000  0.000000
# 2      X0610009L18Rik    0.000000    0.000000  0.00000  0.000000
# 3      X0610010F05Rik    0.000000    0.000000  0.00000  0.000000
# 4      X0610040B10Rik    0.000000    0.000000  0.00000  1.254784
# ...               ...         ...         ...      ...       ...
# 17168             Zyx    3.722419    0.000000  4.55194  2.509567
# 17169           Zzef1    0.000000    0.000000  0.00000  0.000000
# 17170            Zzz3    1.861210    3.844697  2.27597  3.764351
# 17171               a    0.000000    0.000000  0.00000  0.000000
# 17172         ccdc198    0.000000    0.000000  0.00000  0.000000
#
#        Bergmann_mean  MLI1_mean
# 0           0.640783   0.627392
# 1           0.000000   0.000000
# 2           0.000000   0.000000
# 3           0.000000   0.000000
# 4           0.000000   0.627392
# ...              ...        ...
# 17168       1.861210   3.530754
# 17169       0.000000   0.000000
# 17170       2.852954   3.020160
# 17171       0.000000   0.000000
# 17172       0.000000   0.000000
#
# [17173 rows x 7 columns]

# %%
# filter out DE genes get norm counts
DE_sig_200kb_no_dup = DE_sig_200kb_no_dup.merge(norm_counts[["gene","{}_mean".format(cell_type1), "{}_mean".format(cell_type2)]])
DE_sig_200kb_no_dup.to_csv(os.path.join(data_path, "{}_{}_DE_sig_sum_200kb_no_dup.csv".format(cell_type1, cell_type2)), index = False)

# %%
DE_sig_200kb_no_dup
# Out:
#            name  chrom      start        end    gene  100kb name  100kb bin  \
# 0     chr1-4067   chr1  104750000  104775000   Cdh20  chr1-g1047     1047.0
# 1     chr1-4069   chr1  104800000  104825000   Cdh20  chr1-g1048     1048.0
# 2     chr1-4630   chr1  118825000  118850000    Gli2  chr1-g1188     1188.0
# 3     chr1-4637   chr1  119000000  119025000    Gli2  chr1-g1190     1190.0
# 4     chr1-4681   chr1  120100000  120125000     Dbi  chr1-g1201     1201.0
# ..          ...    ...        ...        ...     ...         ...        ...
# 245  chr19-1821  chr19   48600000   48625000  Sorcs3  chr19-g486      486.0
# 246  chr19-1829  chr19   48800000   48825000  Sorcs3  chr19-g488      488.0
# 247    chrX-284   chrX   10475000   10500000  Tspan7   chrX-g104      104.0
# 248   chrX-1462   chrX   41400000   41425000   Gria3   chrX-g414      414.0
# 249   chrX-1470   chrX   41600000   41625000   Gria3   chrX-g416      416.0
#
#      200kb name  200kb bin   baseMean  log2FoldChange     lfcSE      stat  \
# 0     chr1-g523        523  25.158924        5.948869  1.212070  4.908025
# 1     chr1-g524        524  25.158924        5.948869  1.212070  4.908025
# 2     chr1-g594        594   9.630254        6.897208  1.721694  4.006060
# 3     chr1-g595        595   9.630254        6.897208  1.721694  4.006060
# 4     chr1-g600        600  16.304783        3.688433  0.949953  3.882755
# ..          ...        ...        ...             ...       ...       ...
# 245  chr19-g243        243  20.657387       -8.158897  1.585368 -5.146375
# 246  chr19-g244        244  20.657387       -8.158897  1.585368 -5.146375
# 247    chrX-g52         52  31.758453        3.593007  0.683851  5.254075
# 248   chrX-g207        207  13.330310       -6.335799  1.637004 -3.870362
# 249   chrX-g208        208  13.330310       -6.335799  1.637004 -3.870362
#
#            pvalue      padj  category  Bergmann_mean  MLI1_mean
# 0    9.199824e-07  0.000025  Bergmann      96.527182   1.254784
# 1    9.199824e-07  0.000025  Bergmann      96.527182   1.254784
# 2    6.174003e-05  0.000663  Bergmann      36.798574   0.000000
# 3    6.174003e-05  0.000663  Bergmann      36.798574   0.000000
# 4    1.032795e-04  0.001008  Bergmann      52.451313   4.158145
# ..            ...       ...       ...            ...        ...
# 245  2.655688e-07  0.000009      MLI1       0.000000  80.960338
# 246  2.655688e-07  0.000009      MLI1       0.000000  80.960338
# 247  1.487699e-07  0.000006  Bergmann      85.740278   6.667713
# 248  1.086738e-04  0.001037      MLI1       0.000000  22.789701
# 249  1.086738e-04  0.001037      MLI1       0.000000  22.789701
#
# [250 rows x 18 columns]

# %%
temp = {"category" : ",".join, 
        "{}_mean".format(cell_type1) : sum,
        "{}_mean".format(cell_type2) : sum,
        "gene": ",".join}
final_200kb = DE_sig_200kb_no_dup.groupby("200kb name").agg(temp).reset_index()

# %%
final_200kb
# Out:
#     200kb name  category  Bergmann_mean  MLI1_mean    gene
# 0    chr1-g523  Bergmann      96.527182   1.254784   Cdh20
# 1    chr1-g524  Bergmann      96.527182   1.254784   Cdh20
# 2    chr1-g594  Bergmann      36.798574   0.000000    Gli2
# 3    chr1-g595  Bergmann      36.798574   0.000000    Gli2
# 4    chr1-g600  Bergmann      52.451313   4.158145     Dbi
# ..         ...       ...            ...        ...     ...
# 241  chr9-g203      MLI1       0.000000  52.363913    Clmp
# 242  chr9-g312  Bergmann      18.917792   0.000000  Coro2b
# 243  chrX-g207      MLI1       0.000000  22.789701   Gria3
# 244  chrX-g208      MLI1       0.000000  22.789701   Gria3
# 245   chrX-g52  Bergmann      85.740278   6.667713  Tspan7
#
# [246 rows x 5 columns]

# %%
# further format
final_200kb["chrom"]  = final_200kb["200kb name"].str.split("-").str[0]
# add small number to 0
final_200kb = final_200kb.replace(0, 0.05)
final_200kb
# Out:
#     200kb name  category  Bergmann_mean  MLI1_mean    gene chrom
# 0    chr1-g523  Bergmann      96.527182   1.254784   Cdh20  chr1
# 1    chr1-g524  Bergmann      96.527182   1.254784   Cdh20  chr1
# 2    chr1-g594  Bergmann      36.798574   0.050000    Gli2  chr1
# 3    chr1-g595  Bergmann      36.798574   0.050000    Gli2  chr1
# 4    chr1-g600  Bergmann      52.451313   4.158145     Dbi  chr1
# ..         ...       ...            ...        ...     ...   ...
# 241  chr9-g203      MLI1       0.050000  52.363913    Clmp  chr9
# 242  chr9-g312  Bergmann      18.917792   0.050000  Coro2b  chr9
# 243  chrX-g207      MLI1       0.050000  22.789701   Gria3  chrX
# 244  chrX-g208      MLI1       0.050000  22.789701   Gria3  chrX
# 245   chrX-g52  Bergmann      85.740278   6.667713  Tspan7  chrX
#
# [246 rows x 6 columns]

# %%
# rank final output
final_200kb["chrom_id"] = final_200kb["chrom"].str[3:].replace("X", 20).astype(int)
final_200kb["group"] = final_200kb["200kb name"].str.split("-").str[1].str[1:].astype(int)
final_200kb = final_200kb.sort_values(by = ["chrom_id", "group"])
final_200kb["log2FC_{}2{}".format(cell_type1[:1], cell_type2[:1])] =  np.log2(final_200kb["{}_mean".format(cell_type1)].values / final_200kb["{}_mean".format(cell_type2)].values)
final_200kb
# Out:
#      200kb name  category  Bergmann_mean  MLI1_mean    gene  chrom  chrom_id  \
# 0     chr1-g523  Bergmann      96.527182   1.254784   Cdh20   chr1         1
# 1     chr1-g524  Bergmann      96.527182   1.254784   Cdh20   chr1         1
# 2     chr1-g594  Bergmann      36.798574   0.050000    Gli2   chr1         1
# 3     chr1-g595  Bergmann      36.798574   0.050000    Gli2   chr1         1
# 4     chr1-g600  Bergmann      52.451313   4.158145     Dbi   chr1         1
# ..          ...       ...            ...        ...     ...    ...       ...
# 127  chr19-g243      MLI1       0.050000  80.960338  Sorcs3  chr19        19
# 128  chr19-g244      MLI1       0.050000  80.960338  Sorcs3  chr19        19
# 245    chrX-g52  Bergmann      85.740278   6.667713  Tspan7   chrX        20
# 243   chrX-g207      MLI1       0.050000  22.789701   Gria3   chrX        20
# 244   chrX-g208      MLI1       0.050000  22.789701   Gria3   chrX        20
#
#      group  log2FC_B2M
# 0      523    6.265425
# 1      524    6.265425
# 2      594    9.523506
# 3      595    9.523506
# 4      600    3.656967
# ..     ...         ...
# 127    243  -10.661072
# 128    244  -10.661072
# 245     52    3.684709
# 243    207   -8.832238
# 244    208   -8.832238
#
# [246 rows x 9 columns]

# %%
final_200kb.to_csv(os.path.join(data_path, "{}_{}_DE_200kb_FoldChange.csv".format(cell_type1, cell_type2)), index = False)
