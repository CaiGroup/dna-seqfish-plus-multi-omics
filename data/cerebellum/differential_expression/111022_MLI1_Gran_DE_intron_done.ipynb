# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_path = "./intron_DE"
cell_type1 = "Granule"
cell_type2 = "MLI1"

# %%
df = pd.read_csv(os.path.join(data_path, 
                              "deg_deseq2_ensemble_{}_{}.txt".format(cell_type1, cell_type2)), 
                 sep = "\t").reset_index().rename(columns = {"index" : "gene"})
df
# Out:
#           gene    baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0       Slc6a1   68.152806       -5.526105  0.516307 -10.703139  9.838740e-27
# 1      Galnt18   52.537974       -5.336412  0.505850 -10.549399  5.112298e-26
# 2        Psg19  453.987662       -1.860533  0.189786  -9.803308  1.089581e-22
# 3         Bcan   46.221746       -5.090703  0.546169  -9.320741  1.155310e-20
# 4        Grid2   92.325989       -5.109399  0.578880  -8.826346  1.081516e-18
# ...        ...         ...             ...       ...        ...           ...
# 17168      Zyx    2.441769        0.338843  1.906239   0.177755  8.589156e-01
# 17169    Zzef1    0.789444        0.200871  3.862284   0.052008  9.585221e-01
# 17170     Zzz3    3.571956        0.232729  1.474502   0.157836  8.745864e-01
# 17171        a    0.000000             NaN       NaN        NaN           NaN
# 17172  ccdc198    0.208651       -1.190900  4.981898  -0.239046  8.110703e-01
#
#                padj
# 0      8.451477e-24
# 1      2.195732e-23
# 2      3.119833e-20
# 3      2.481029e-18
# 4      1.858044e-16
# ...             ...
# 17168           NaN
# 17169           NaN
# 17170           NaN
# 17171           NaN
# 17172           NaN
#
# [17173 rows x 7 columns]

# %%
plt.scatter(df["log2FoldChange"], -np.log10(df["padj"]) , s = 2)

# %% [markdown]
# # use log fold change 2 / -2 as cuttoff

# %%
df[(df["padj"] < 0.01) & (df["log2FoldChange"] > 2)]
# Out:
#         gene   baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 13      Grm4  70.520529        7.206051  1.088692  6.618998  3.616424e-11
# 17     Rims1  39.683681        3.879651  0.625430  6.203179  5.533383e-10
# 19    Tubb4a  44.541711        3.362204  0.554079  6.068096  1.294354e-09
# 26     Dusp5  28.622578        4.994108  0.959509  5.204860  1.941430e-07
# 27     Kcnc1  32.046905        5.947115  1.145780  5.190451  2.097856e-07
# 30       Bsn  27.876360        3.489118  0.696271  5.011151  5.410538e-07
# 34    Gm2694  18.280149        7.750584  1.585511  4.888382  1.016681e-06
# 35    Atp2b2  39.450783        3.490069  0.720671  4.842803  1.280205e-06
# 42    Grin2a  14.530953        7.457421  1.645693  4.531479  5.857215e-06
# 44     Caln1  28.157477        2.792065  0.631061  4.424396  9.671259e-06
# 48    Diras2  17.465793        5.288348  1.224184  4.319895  1.561038e-05
# 49     Camk4  11.708139        7.078049  1.660937  4.261479  2.030785e-05
# 51    Coro2b  24.219169        6.566739  1.549244  4.238674  2.248441e-05
# 52     Prrt1  45.256718        2.259569  0.535581  4.218913  2.454827e-05
# 53      Ece1  18.377712        6.618300  1.575053  4.201955  2.646201e-05
# 55    Cnksr3  19.737116        6.156464  1.472307  4.181509  2.895806e-05
# 56   Tmem266  16.809541        5.276868  1.264979  4.171506  3.025926e-05
# 57     Ntrk3  21.087636        6.040268  1.458373  4.141785  3.446132e-05
# 58    Lrrc3b  15.666133        5.085054  1.230063  4.133978  3.565369e-05
# 60    Plcxd3  34.535915        2.357832  0.571912  4.122716  3.744311e-05
# 63    Rbfox3  15.516874        6.150312  1.541440  3.989979  6.607907e-05
# 67     Abca2  28.345406        2.737045  0.705133  3.881603  1.037703e-04
# 71    Rnf182  11.168538        6.296050  1.645355  3.826560  1.299463e-04
# 74     Sez6l  16.837783        6.052154  1.607329  3.765349  1.663168e-04
# 75      Nav2  19.285104        3.311285  0.888077  3.728600  1.925463e-04
# 80      Chn2  12.495908        5.765814  1.574846  3.661192  2.510445e-04
# 81    Hs3st1  30.031081        2.473414  0.679787  3.638515  2.742144e-04
# 82     Car10  11.497116        5.940784  1.645317  3.610724  3.053432e-04
# 87    Grin2c   7.214900        6.279958  1.775109  3.537787  4.034950e-04
# 90    Fbxl22  11.174812        5.578701  1.590191  3.508195  4.511580e-04
# 93     Stmn2  11.835162        4.479940  1.310772  3.417787  6.313259e-04
# 95    Cadps2  10.854062        4.536230  1.336656  3.393715  6.895142e-04
# 96     Kcnk3  10.566850        3.911177  1.173483  3.332964  8.592611e-04
# 98       Boc   6.239357        6.108486  1.842364  3.315569  9.145681e-04
# 99     Adcy1  15.922425        3.131106  0.948000  3.302856  9.570563e-04
# 100   Spred2   5.988813        6.034223  1.825893  3.304806  9.504206e-04
# 102   Hpcal1  32.270742        4.693204  1.426143  3.290838  9.988953e-04
# 103   Nmnat2  13.992452        3.416721  1.048315  3.259249  1.117074e-03
# 104     Xkr6  19.704868        2.838391  0.870780  3.259596  1.115712e-03
# 106     Il16   5.906456        5.894704  1.819532  3.239681  1.196637e-03
#
#              padj
# 13   2.218934e-09
# 17   2.640653e-08
# 19   5.559251e-08
# 26   6.176622e-06
# 27   6.435921e-06
# 30   1.499243e-05
# 34   2.495226e-05
# 35   3.054712e-05
# 42   1.170081e-04
# 44   1.846136e-04
# 48   2.736595e-04
# 49   3.488888e-04
# 51   3.715606e-04
# 52   3.978673e-04
# 53   4.209420e-04
# 55   4.441960e-04
# 56   4.560124e-04
# 57   5.103840e-04
# 58   5.190936e-04
# 60   5.355098e-04
# 63   8.869051e-04
# 67   1.310864e-03
# 71   1.550331e-03
# 74   1.904881e-03
# 75   2.176280e-03
# 80   2.662312e-03
# 81   2.872563e-03
# 82   3.160118e-03
# 87   3.894406e-03
# 90   4.258733e-03
# 93   5.769244e-03
# 95   6.169716e-03
# 96   7.609333e-03
# 98   7.935495e-03
# 99   8.139716e-03
# 100  8.139716e-03
# 102  8.330593e-03
# 103  9.138733e-03
# 104  9.138733e-03
# 106  9.606645e-03

# %%
df[(df["padj"] < 0.01) & (df["log2FoldChange"] < -2)]
# Out:
#         gene   baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0     Slc6a1  68.152806       -5.526105  0.516307 -10.703139  9.838740e-27
# 1    Galnt18  52.537974       -5.336412  0.505850 -10.549399  5.112298e-26
# 3       Bcan  46.221746       -5.090703  0.546169  -9.320741  1.155310e-20
# 4      Grid2  92.325989       -5.109399  0.578880  -8.826346  1.081516e-18
# 5      Myo16  38.919751       -4.986025  0.581817  -8.569745  1.037145e-17
# ..       ...        ...             ...       ...        ...           ...
# 91    Thsd7a   8.108073       -5.016777  1.452448  -3.454016  5.523044e-04
# 92    Dusp15   9.426970       -3.494750  1.019233  -3.428805  6.062444e-04
# 94     Asap1   6.224078       -4.647812  1.363020  -3.409936  6.497804e-04
# 97     Auts2  16.184179       -4.579109  1.378821  -3.321033  8.968505e-04
# 101  Marchf4   6.430029       -4.245740  1.287260  -3.298278  9.727973e-04
#
#              padj
# 0    8.451477e-24
# 1    2.195732e-23
# 3    2.481029e-18
# 4    1.858044e-16
# 5    1.484846e-15
# ..            ...
# 91   5.156842e-03
# 92   5.599612e-03
# 94   5.875383e-03
# 97   7.861169e-03
# 101  8.192479e-03
#
# [61 rows x 7 columns]

# %% [markdown]
# # proceed with threshold 2 first

# %%
# check foldchange Granule cell marker gene
df[df["gene"].isin(["Lypd6", "Gabra6"])]
# fold change is calculated by granule / MLI1
# Out:
#         gene  baseMean  log2FoldChange     lfcSE      stat    pvalue  padj
# 6643  Gabra6  1.925380        2.217802  2.467011  0.898983  0.368662   NaN
# 9363   Lypd6  4.437362       -0.169487  1.533004 -0.110559  0.911966   NaN

# %%
category = np.zeros(df.shape[0]).astype(object)
category[(df["padj"] < 0.01) & (df["log2FoldChange"] > 2)] = cell_type1
category[(df["padj"] < 0.01) & (df["log2FoldChange"] < -2)] = cell_type2

# %%
df["category"] = category
df.head()
# Out:
#       gene    baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0   Slc6a1   68.152806       -5.526105  0.516307 -10.703139  9.838740e-27
# 1  Galnt18   52.537974       -5.336412  0.505850 -10.549399  5.112298e-26
# 2    Psg19  453.987662       -1.860533  0.189786  -9.803308  1.089581e-22
# 3     Bcan   46.221746       -5.090703  0.546169  -9.320741  1.155310e-20
# 4    Grid2   92.325989       -5.109399  0.578880  -8.826346  1.081516e-18
#
#            padj category
# 0  8.451477e-24     MLI1
# 1  2.195732e-23     MLI1
# 2  3.119833e-20      0.0
# 3  2.481029e-18     MLI1
# 4  1.858044e-16     MLI1

# %%
df[df["gene"].isin(["Lypd6","Gabra6"])]
# Out:
#         gene  baseMean  log2FoldChange     lfcSE      stat    pvalue  padj  \
# 6643  Gabra6  1.925380        2.217802  2.467011  0.898983  0.368662   NaN
# 9363   Lypd6  4.437362       -0.169487  1.533004 -0.110559  0.911966   NaN
#
#      category
# 6643      0.0
# 9363      0.0

# %%
plt.scatter(df[df["category"] == cell_type1]["log2FoldChange"], -np.log10(df[df["category"] == cell_type1]["padj"]), label = cell_type1)
plt.scatter(df[df["category"] == cell_type2]["log2FoldChange"], -np.log10(df[df["category"] == cell_type2]["padj"]), label = cell_type2 )
plt.scatter(df[df["category"] == 0]["log2FoldChange"], -np.log10(df[df["category"] == 0]["padj"]), label = "non sig" )
plt.legend()

# %%
DE_genes = df[df["category"] != 0]
DE_genes
# Out:
#         gene   baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0     Slc6a1  68.152806       -5.526105  0.516307 -10.703139  9.838740e-27
# 1    Galnt18  52.537974       -5.336412  0.505850 -10.549399  5.112298e-26
# 3       Bcan  46.221746       -5.090703  0.546169  -9.320741  1.155310e-20
# 4      Grid2  92.325989       -5.109399  0.578880  -8.826346  1.081516e-18
# 5      Myo16  38.919751       -4.986025  0.581817  -8.569745  1.037145e-17
# ..       ...        ...             ...       ...        ...           ...
# 101  Marchf4   6.430029       -4.245740  1.287260  -3.298278  9.727973e-04
# 102   Hpcal1  32.270742        4.693204  1.426143   3.290838  9.988953e-04
# 103   Nmnat2  13.992452        3.416721  1.048315   3.259249  1.117074e-03
# 104     Xkr6  19.704868        2.838391  0.870780   3.259596  1.115712e-03
# 106     Il16   5.906456        5.894704  1.819532   3.239681  1.196637e-03
#
#              padj category
# 0    8.451477e-24     MLI1
# 1    2.195732e-23     MLI1
# 3    2.481029e-18     MLI1
# 4    1.858044e-16     MLI1
# 5    1.484846e-15     MLI1
# ..            ...      ...
# 101  8.192479e-03     MLI1
# 102  8.330593e-03  Granule
# 103  9.138733e-03  Granule
# 104  9.138733e-03  Granule
# 106  9.606645e-03  Granule
#
# [101 rows x 8 columns]

# %% [markdown]
# # Map back to genome

# %%
meta = pd.read_csv(os.path.join("../annot", "Final", "mm10_25kb_bins_genes_09022022.csv"))
meta = meta[["name", "chrom", "start", "end", "gene", "100kb name", "100kb bin", "200kb name", "200kb bin"]]
meta["gene"] = meta["gene"].str.replace("-", ".")
meta["gene"] = meta["gene"].str.replace("March", "Marchf")
meta["gene"] = meta["gene"].str.replace("Sept", "Septin")

# %% [markdown]
# # Mismatch between DE gene naming and annotated namming

# %%
DE_sig_25kb = meta.merge(DE_genes)

# %% [markdown]
# # OK! tried our best to get all genes

# %%
DE_sig_25kb["200kb bin"] = DE_sig_25kb["start"] // 200000
DE_sig_25kb["200kb name"] = DE_sig_25kb["chrom"] + "-g" + DE_sig_25kb["200kb bin"].astype(str)

# %%
cols = ["200kb name","chrom", "200kb bin", "gene", "baseMean", "log2FoldChange", "pvalue", "padj", "category"]

# %%
DE_sig_200kb = DE_sig_25kb.copy()

# %%
DE_sig_200kb_no_dup = DE_sig_200kb.drop_duplicates(subset=["gene", "200kb name"], keep='first')
DE_sig_200kb_no_dup
# Out:
#             name  chrom     start       end     gene  100kb name  100kb bin  \
# 0       chr1-772   chr1  22275000  22300000    Rims1   chr1-g222      222.0
# 5       chr1-777   chr1  22400000  22425000    Rims1   chr1-g224      224.0
# 13      chr1-785   chr1  22600000  22625000    Rims1   chr1-g226      226.0
# 21      chr1-793   chr1  22800000  22825000    Rims1   chr1-g228      228.0
# 22     chr1-2778   chr1  72425000  72450000  Marchf4   chr1-g724      724.0
# ...          ...    ...       ...       ...      ...         ...        ...
# 1099  chr19-1821  chr19  48600000  48625000   Sorcs3  chr19-g486      486.0
# 1107  chr19-1829  chr19  48800000  48825000   Sorcs3  chr19-g488      488.0
# 1108  chr19-2018  chr19  53525000  53550000    Dusp5  chr19-g535      535.0
# 1109   chrX-1462   chrX  41400000  41425000    Gria3   chrX-g414      414.0
# 1117   chrX-1470   chrX  41600000  41625000    Gria3   chrX-g416      416.0
#
#       200kb name  200kb bin   baseMean  log2FoldChange     lfcSE      stat  \
# 0      chr1-g111        111  39.683681        3.879651  0.625430  6.203179
# 5      chr1-g112        112  39.683681        3.879651  0.625430  6.203179
# 13     chr1-g113        113  39.683681        3.879651  0.625430  6.203179
# 21     chr1-g114        114  39.683681        3.879651  0.625430  6.203179
# 22     chr1-g362        362   6.430029       -4.245740  1.287260 -3.298278
# ...          ...        ...        ...             ...       ...       ...
# 1099  chr19-g243        243  20.657387       -8.209330  1.228922 -6.680106
# 1107  chr19-g244        244  20.657387       -8.209330  1.228922 -6.680106
# 1108  chr19-g267        267  28.622578        4.994108  0.959509  5.204860
# 1109   chrX-g207        207  13.330310       -5.375931  1.066768 -5.039458
# 1117   chrX-g208        208  13.330310       -5.375931  1.066768 -5.039458
#
#             pvalue          padj category
# 0     5.533383e-10  2.640653e-08  Granule
# 5     5.533383e-10  2.640653e-08  Granule
# 13    5.533383e-10  2.640653e-08  Granule
# 21    5.533383e-10  2.640653e-08  Granule
# 22    9.727973e-04  8.192479e-03     MLI1
# ...            ...           ...      ...
# 1099  2.387688e-11  1.577711e-09     MLI1
# 1107  2.387688e-11  1.577711e-09     MLI1
# 1108  1.941430e-07  6.176622e-06  Granule
# 1109  4.668516e-07  1.336752e-05     MLI1
# 1117  4.668516e-07  1.336752e-05     MLI1
#
# [226 rows x 16 columns]

# %%
# get norm counts
norm_counts = pd.read_csv(os.path.join(data_path, 
                                       "ensembl_gene_counts_normalized.txt"), sep = "\t")

idx = (norm_counts.iloc[0].isin([cell_type1 ,cell_type2, "CLUSTER"])).values

norm_counts = norm_counts.iloc[:, idx]

# take a look
norm_counts.head()
# Out:
#                ID                1.1                2.1   1.2  \
# 0         CLUSTER            Granule            Granule  MLI1
# 1  X0610005C13Rik  0.360020332406605  0.695614535929326     0
# 2  X0610009B22Rik                  0  0.463743023952884     0
# 3  X0610009L18Rik   1.44008132962642   2.78245814371731     0
# 4  X0610010F05Rik   2.88016265925284   1.62310058383509     0
#
#                 2.2
# 0              MLI1
# 1  1.25478353316771
# 2                 0
# 3                 0
# 4                 0

# %%
n1 = ["{}_{}".format(cell_type1, i) for i in range(1, 3)]
n2 = ["{}_{}".format(cell_type2, i) for i in range(1, 3)]

norm_counts.columns = ['gene'] + n1 + n2
norm_counts = norm_counts.iloc[1:].reset_index(drop = True)
norm_counts.head()
# turn dataframes to numeric
norm_counts[n1 + n2] = norm_counts[n1 + n2].apply(pd.to_numeric, errors='coerce')

# %%
norm_counts["{}_mean".format(cell_type1)] = norm_counts[n1].mean(axis=1)
norm_counts["{}_mean".format(cell_type2)] = norm_counts[n2].mean(axis=1)
norm_counts
# Out:
#                  gene  Granule_1  Granule_2   MLI1_1    MLI1_2  Granule_mean  \
# 0      X0610005C13Rik   0.360020   0.695615  0.00000  1.254784      0.527817
# 1      X0610009B22Rik   0.000000   0.463743  0.00000  0.000000      0.231872
# 2      X0610009L18Rik   1.440081   2.782458  0.00000  0.000000      2.111270
# 3      X0610010F05Rik   2.880163   1.623101  0.00000  0.000000      2.251632
# 4      X0610040B10Rik   0.000000   0.927486  0.00000  1.254784      0.463743
# ...               ...        ...        ...      ...       ...           ...
# 17168             Zyx   5.040285   3.709944  4.55194  2.509567      4.375114
# 17169           Zzef1   0.000000   0.695615  0.00000  0.000000      0.347807
# 17170            Zzz3   2.880163   4.405559  2.27597  3.764351      3.642861
# 17171               a   0.000000   0.000000  0.00000  0.000000      0.000000
# 17172         ccdc198   0.000000   0.231872  0.00000  0.000000      0.115936
#
#        MLI1_mean
# 0       0.627392
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.627392
# ...          ...
# 17168   3.530754
# 17169   0.000000
# 17170   3.020160
# 17171   0.000000
# 17172   0.000000
#
# [17173 rows x 7 columns]

# %%
# filter out DE genes get norm counts
DE_sig_200kb_no_dup = DE_sig_200kb_no_dup.merge(norm_counts[["gene","{}_mean".format(cell_type1), "{}_mean".format(cell_type2)]])
DE_sig_200kb_no_dup.to_csv(os.path.join(data_path, 
                                        "{}_{}_DE_sig_sum_200kb_no_dup.csv".format(cell_type1, cell_type2)), index = None)

# %%
DE_sig_200kb_no_dup
# Out:
#            name  chrom     start       end     gene  100kb name  100kb bin  \
# 0      chr1-772   chr1  22275000  22300000    Rims1   chr1-g222      222.0
# 1      chr1-777   chr1  22400000  22425000    Rims1   chr1-g224      224.0
# 2      chr1-785   chr1  22600000  22625000    Rims1   chr1-g226      226.0
# 3      chr1-793   chr1  22800000  22825000    Rims1   chr1-g228      228.0
# 4     chr1-2778   chr1  72425000  72450000  Marchf4   chr1-g724      724.0
# ..          ...    ...       ...       ...      ...         ...        ...
# 221  chr19-1821  chr19  48600000  48625000   Sorcs3  chr19-g486      486.0
# 222  chr19-1829  chr19  48800000  48825000   Sorcs3  chr19-g488      488.0
# 223  chr19-2018  chr19  53525000  53550000    Dusp5  chr19-g535      535.0
# 224   chrX-1462   chrX  41400000  41425000    Gria3   chrX-g414      414.0
# 225   chrX-1470   chrX  41600000  41625000    Gria3   chrX-g416      416.0
#
#      200kb name  200kb bin   baseMean  log2FoldChange     lfcSE      stat  \
# 0     chr1-g111        111  39.683681        3.879651  0.625430  6.203179
# 1     chr1-g112        112  39.683681        3.879651  0.625430  6.203179
# 2     chr1-g113        113  39.683681        3.879651  0.625430  6.203179
# 3     chr1-g114        114  39.683681        3.879651  0.625430  6.203179
# 4     chr1-g362        362   6.430029       -4.245740  1.287260 -3.298278
# ..          ...        ...        ...             ...       ...       ...
# 221  chr19-g243        243  20.657387       -8.209330  1.228922 -6.680106
# 222  chr19-g244        244  20.657387       -8.209330  1.228922 -6.680106
# 223  chr19-g267        267  28.622578        4.994108  0.959509  5.204860
# 224   chrX-g207        207  13.330310       -5.375931  1.066768 -5.039458
# 225   chrX-g208        208  13.330310       -5.375931  1.066768 -5.039458
#
#            pvalue          padj category  Granule_mean  MLI1_mean
# 0    5.533383e-10  2.640653e-08  Granule    139.466110   9.060481
# 1    5.533383e-10  2.640653e-08  Granule    139.466110   9.060481
# 2    5.533383e-10  2.640653e-08  Granule    139.466110   9.060481
# 3    5.533383e-10  2.640653e-08  Granule    139.466110   9.060481
# 4    9.727973e-04  8.192479e-03     MLI1      0.591892  10.825858
# ..            ...           ...      ...           ...        ...
# 221  2.387688e-11  1.577711e-09     MLI1      0.231872  80.960338
# 222  2.387688e-11  1.577711e-09     MLI1      0.231872  80.960338
# 223  1.941430e-07  6.176622e-06  Granule    101.334929   3.020160
# 224  4.668516e-07  1.336752e-05     MLI1      0.527817  22.789701
# 225  4.668516e-07  1.336752e-05     MLI1      0.527817  22.789701
#
# [226 rows x 18 columns]

# %%
temp = {"category" : ",".join, 
        "{}_mean".format(cell_type1) : sum,
        "{}_mean".format(cell_type2) : sum,
        "gene": ",".join}
final_200kb = DE_sig_200kb_no_dup.groupby("200kb name").agg(temp).reset_index()

# %%
final_200kb
# Out:
#     200kb name category  Granule_mean  MLI1_mean     gene
# 0    chr1-g111  Granule    139.466110   9.060481    Rims1
# 1    chr1-g112  Granule    139.466110   9.060481    Rims1
# 2    chr1-g113  Granule    139.466110   9.060481    Rims1
# 3    chr1-g114  Granule    139.466110   9.060481    Rims1
# 4    chr1-g362     MLI1      0.591892  10.825858  Marchf4
# ..         ...      ...           ...        ...      ...
# 221  chr9-g345     MLI1      5.046303  39.028488     Rora
# 222  chr9-g346     MLI1      5.046303  39.028488     Rora
# 223  chr9-g540  Granule     87.624066   7.295104      Bsn
# 224  chrX-g207     MLI1      0.527817  22.789701    Gria3
# 225  chrX-g208     MLI1      0.527817  22.789701    Gria3
#
# [226 rows x 5 columns]

# %%
# further format
final_200kb["chrom"]  = final_200kb["200kb name"].str.split("-").str[0]
# add small number to 0
final_200kb = final_200kb.replace(0, 0.05)
final_200kb
# Out:
#     200kb name category  Granule_mean  MLI1_mean     gene chrom
# 0    chr1-g111  Granule    139.466110   9.060481    Rims1  chr1
# 1    chr1-g112  Granule    139.466110   9.060481    Rims1  chr1
# 2    chr1-g113  Granule    139.466110   9.060481    Rims1  chr1
# 3    chr1-g114  Granule    139.466110   9.060481    Rims1  chr1
# 4    chr1-g362     MLI1      0.591892  10.825858  Marchf4  chr1
# ..         ...      ...           ...        ...      ...   ...
# 221  chr9-g345     MLI1      5.046303  39.028488     Rora  chr9
# 222  chr9-g346     MLI1      5.046303  39.028488     Rora  chr9
# 223  chr9-g540  Granule     87.624066   7.295104      Bsn  chr9
# 224  chrX-g207     MLI1      0.527817  22.789701    Gria3  chrX
# 225  chrX-g208     MLI1      0.527817  22.789701    Gria3  chrX
#
# [226 rows x 6 columns]

# %%
# rank final output
final_200kb["chrom_id"] = final_200kb["chrom"].str[3:].replace("X", 20).astype(int)
final_200kb["group"] = final_200kb["200kb name"].str.split("-").str[1].str[1:].astype(int)
final_200kb = final_200kb.sort_values(by = ["chrom_id", "group"])
final_200kb["log2FC_{}2{}".format(cell_type1[:1], cell_type2[:1])] =  np.log2(final_200kb["{}_mean".format(cell_type1)].values / final_200kb["{}_mean".format(cell_type2)].values)
final_200kb
# Out:
#      200kb name category  Granule_mean  MLI1_mean     gene  chrom  chrom_id  \
# 0     chr1-g111  Granule    139.466110   9.060481    Rims1   chr1         1
# 1     chr1-g112  Granule    139.466110   9.060481    Rims1   chr1         1
# 2     chr1-g113  Granule    139.466110   9.060481    Rims1   chr1         1
# 3     chr1-g114  Granule    139.466110   9.060481    Rims1   chr1         1
# 4     chr1-g362     MLI1      0.591892  10.825858  Marchf4   chr1         1
# ..          ...      ...           ...        ...      ...    ...       ...
# 107  chr19-g243     MLI1      0.231872  80.960338   Sorcs3  chr19        19
# 108  chr19-g244     MLI1      0.231872  80.960338   Sorcs3  chr19        19
# 109  chr19-g267  Granule    101.334929   3.020160    Dusp5  chr19        19
# 224   chrX-g207     MLI1      0.527817  22.789701    Gria3   chrX        20
# 225   chrX-g208     MLI1      0.527817  22.789701    Gria3   chrX        20
#
#      group  log2FC_G2M
# 0      111    3.944183
# 1      112    3.944183
# 2      113    3.944183
# 3      114    3.944183
# 4      362   -4.193004
# ..     ...         ...
# 107    243   -8.447746
# 108    244   -8.447746
# 109    267    5.068363
# 224    207   -5.432199
# 225    208   -5.432199
#
# [226 rows x 9 columns]

# %%
final_200kb.to_csv(os.path.join(data_path, "{}_{}_DE_200kb_FoldChange.csv".format(cell_type1, cell_type2)), index = False)
