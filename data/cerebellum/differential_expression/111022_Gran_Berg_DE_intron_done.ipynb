# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/yujing/miniconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
data_path = "./intron_DE"
cell_type1 = "Bergmann"
cell_type2 = "Granule"

# %%
df = pd.read_csv(os.path.join(data_path, 
                              "deg_deseq2_ensemble_{}_{}.txt".format(cell_type1, cell_type2)), 
                 sep = "\t").reset_index().rename(columns = {"index" : "gene"})
df
# Out:
#           gene    baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0      Fam107a  104.456630        7.208201  0.485089  14.859555  6.032473e-50
# 1      Septin4   85.370323        5.643409  0.396362  14.238036  5.320149e-46
# 2        Psg19  453.987662        2.610535  0.185950  14.038891  9.011221e-45
# 3          Id4   56.763669        6.338308  0.522475  12.131312  7.208539e-34
# 4           Qk   57.442895        5.677895  0.485392  11.697539  1.312042e-31
# ...        ...         ...             ...       ...        ...           ...
# 17168      Zyx    2.441769       -1.336732  2.011587  -0.664516  5.063602e-01
# 17169    Zzef1    0.789444       -0.330711  3.862205  -0.085627  9.317626e-01
# 17170     Zzz3    3.571956       -0.320501  1.468255  -0.218287  8.272055e-01
# 17171        a    0.000000             NaN       NaN        NaN           NaN
# 17172  ccdc198    0.208651        1.061044  4.981742   0.212986  8.313375e-01
#
#                padj
# 0      7.172611e-47
# 1      3.162829e-43
# 2      3.571447e-42
# 3      2.142738e-31
# 4      3.120035e-29
# ...             ...
# 17168           NaN
# 17169           NaN
# 17170           NaN
# 17171           NaN
# 17172           NaN
#
# [17173 rows x 7 columns]

# %%
plt.scatter(df["log2FoldChange"], -np.log10(df["padj"]) , s = 2)

# %% [markdown]
# # use log fold change 2 / -2 as cuttoff

# %%
df[(df["padj"] < 0.01) & (df["log2FoldChange"] > 2)]
# Out:
#         gene    baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0    Fam107a  104.456630        7.208201  0.485089  14.859555  6.032473e-50
# 1    Septin4   85.370323        5.643409  0.396362  14.238036  5.320149e-46
# 2      Psg19  453.987662        2.610535  0.185950  14.038891  9.011221e-45
# 3        Id4   56.763669        6.338308  0.522475  12.131312  7.208539e-34
# 4         Qk   57.442895        5.677895  0.485392  11.697539  1.312042e-31
# ..       ...         ...             ...       ...        ...           ...
# 173    Cntfr   16.522247        2.619643  0.815952   3.210534  1.324884e-03
# 175   Zfp608    4.733889        6.056225  1.890119   3.204149  1.354622e-03
# 176     Tnik    9.525609        3.568729  1.115855   3.198201  1.382878e-03
# 177    Traf4    9.104378        3.197841  1.000233   3.197096  1.388188e-03
# 180   Frmpd1    4.284401        4.776915  1.502470   3.179375  1.475932e-03
#
#              padj
# 0    7.172611e-47
# 1    3.162829e-43
# 2    3.571447e-42
# 3    2.142738e-31
# 4    3.120035e-29
# ..            ...
# 173  9.053373e-03
# 175  9.151393e-03
# 176  9.272786e-03
# 177  9.272786e-03
# 180  9.683608e-03
#
# [128 rows x 7 columns]

# %%
df[(df["padj"] < 0.01) & (df["log2FoldChange"] < -2)]
# Out:
#          gene    baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 8         Ipw  219.906609       -2.813272  0.269633 -10.433710  1.739602e-25
# 37      Rims1   39.683681       -3.843412  0.610434  -6.296199  3.050323e-10
# 41       Grm4   70.520529       -2.860932  0.463260  -6.175655  6.588984e-10
# 48     Tubb4a   44.541711       -3.092371  0.525140  -5.888661  3.893362e-09
# 52     Plcxd3   34.535915       -3.832533  0.673753  -5.688334  1.282845e-08
# 59      Caln1   28.157477       -4.203363  0.780030  -5.388718  7.096201e-08
# 61     Sh3gl2   40.419966       -3.284749  0.624836  -5.256982  1.464389e-07
# 67        Bsn   27.876360       -3.531483  0.687962  -5.133252  2.847778e-07
# 72     Hs3st1   30.031081       -4.359207  0.869787  -5.011810  5.392033e-07
# 75      Nptx1   41.760831       -4.462491  0.924256  -4.828198  1.377743e-06
# 79      Dusp5   28.622578       -3.568695  0.753533  -4.735954  2.180274e-06
# 81      Kcnc1   32.046905       -2.828542  0.598150  -4.728821  2.258272e-06
# 82    St8sia5   34.182321       -4.223190  0.899174  -4.696742  2.643443e-06
# 83       Lgi3   24.111137       -4.138428  0.901643  -4.589875  4.435125e-06
# 84      Pgbd5   37.518734       -3.555143  0.775675  -4.583290  4.577170e-06
# 86        Syp   27.606639       -3.369700  0.738793  -4.561089  5.088891e-06
# 90     Phyhip   27.761864       -3.614632  0.800111  -4.517664  6.252572e-06
# 95     Diras2   17.465793       -4.468066  1.004036  -4.450105  8.582836e-06
# 99     Gm2694   18.280149       -3.858790  0.882825  -4.370959  1.237020e-05
# 103   Ppp2r2c   29.133997       -3.162778  0.744149  -4.250195  2.135841e-05
# 105    Atp2b2   39.450783       -2.530188  0.599429  -4.220996  2.432249e-05
# 107    Rbfox3   15.516874       -4.737153  1.138957  -4.159204  3.193586e-05
# 108     Srrm4   23.161629       -6.302331  1.523884  -4.135703  3.538690e-05
# 110   Tmem266   16.809541       -3.743286  0.925332  -4.045342  5.224672e-05
# 116    Lrrc3b   15.666133       -3.630638  0.909946  -3.989947  6.608818e-05
# 117    Grin2a   14.530953       -4.596985  1.155030  -3.979971  6.892356e-05
# 118      Dnm1   27.277623       -3.017413  0.763620  -3.951460  7.767581e-05
# 121      Xkr6   19.704868       -4.212529  1.079098  -3.903751  9.471324e-05
# 125     Olfm1   10.215204       -6.772925  1.764680  -3.838047  1.240167e-04
# 126     Lrrn1   24.242866       -3.809239  1.000846  -3.806019  1.412214e-04
# 129    Eef1a2   22.594401       -3.207098  0.850666  -3.770104  1.631795e-04
# 136   Cacna1a   25.669116       -3.761484  1.038136  -3.623305  2.908620e-04
# 138   Phactr3   25.176160       -2.415690  0.671259  -3.598743  3.197587e-04
# 142     Wscd2   13.451831       -5.618564  1.571710  -3.574810  3.504829e-04
# 143    Mical3   17.047931       -3.252937  0.914038  -3.558863  3.724632e-04
# 148      Ece1   18.377712       -3.353450  0.965925  -3.471749  5.170797e-04
# 151      Sncb   22.197801       -3.043669  0.882718  -3.448064  5.646192e-04
# 152      Mapt   13.608093       -5.551866  1.616611  -3.434263  5.941667e-04
# 153     Adcy1   15.922425       -3.246914  0.947089  -3.428311  6.073486e-04
# 154     Camk4   11.708139       -3.717520  1.085823  -3.423689  6.177730e-04
# 155      Chn2   12.495908       -3.600612  1.051211  -3.425202  6.143419e-04
# 160      Meg3   49.370985       -2.251620  0.664244  -3.389747  6.995724e-04
# 163     Abca2   28.345406       -2.216987  0.663921  -3.339233  8.401016e-04
# 166     Kcnk3   10.566850       -3.614634  1.095672  -3.299010  9.702631e-04
# 167    Cadps2   10.854062       -3.751261  1.143552  -3.280359  1.036751e-03
# 168     Ptprn   13.615277       -3.620657  1.107387  -3.269549  1.077191e-03
# 169    Nmnat2   13.992452       -3.241883  0.999785  -3.242580  1.184528e-03
# 174     Ntrk3   21.087636       -2.165315  0.675207  -3.206891  1.341778e-03
# 178  Arhgap44    8.194360       -5.452027  1.711508  -3.185512  1.444983e-03
# 179    Ergic1   19.284781       -2.728129  0.858406  -3.178133  1.482268e-03
# 181     Panx2    8.686743       -5.230540  1.645293  -3.179093  1.477369e-03
#
#              padj
# 8    2.298208e-23
# 37   9.544300e-09
# 41   1.865310e-08
# 48   9.447363e-08
# 52   2.877929e-07
# 59   1.406230e-06
# 61   2.808321e-06
# 67   4.979423e-06
# 72   8.824928e-06
# 75   2.155443e-05
# 79   3.240432e-05
# 81   3.274494e-05
# 82   3.786811e-05
# 83   6.277814e-05
# 84   6.402652e-05
# 86   7.024825e-05
# 90   8.185922e-05
# 95   1.063020e-04
# 99   1.470816e-04
# 103  2.441841e-04
# 105  2.728249e-04
# 107  3.515902e-04
# 108  3.860094e-04
# 110  5.596518e-04
# 116  6.716141e-04
# 117  6.944925e-04
# 118  7.761054e-04
# 121  9.230659e-04
# 125  1.170284e-03
# 126  1.322143e-03
# 129  1.492464e-03
# 136  2.524342e-03
# 138  2.735202e-03
# 142  2.914155e-03
# 143  3.064378e-03
# 148  4.098718e-03
# 151  4.416660e-03
# 152  4.617413e-03
# 153  4.689204e-03
# 154  4.697754e-03
# 155  4.697754e-03
# 160  5.166407e-03
# 163  6.090736e-03
# 166  6.908041e-03
# 167  7.337481e-03
# 168  7.578580e-03
# 169  8.284731e-03
# 174  9.116422e-03
# 178  9.598241e-03
# 179  9.683608e-03
# 181  9.683608e-03

# %% [markdown]
# # proceed with threshold 2 first

# %%
# check foldchange Granule cell marker gene
df[df["gene"].isin(["Gabra6", "Gdf10"])]
# fold change is calculated by granule / purkinje
# Out:
#         gene   baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 25     Gdf10  34.674536        8.917572  1.178480  7.567013  3.819048e-14
# 6869  Gabra6   1.925380       -4.503076  2.623057 -1.716728  8.602879e-02
#
#               padj
# 25    1.746480e-12
# 6869           NaN

# %%
category = np.zeros(df.shape[0]).astype(object)
category[(df["padj"] < 0.01) & (df["log2FoldChange"] > 2)] = cell_type1
category[(df["padj"] < 0.01) & (df["log2FoldChange"] < -2)] = cell_type2

# %%
df["category"] = category
df[df["gene"].isin(["Gabra6", "Gdf10"])]
# Out:
#         gene   baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 25     Gdf10  34.674536        8.917572  1.178480  7.567013  3.819048e-14
# 6869  Gabra6   1.925380       -4.503076  2.623057 -1.716728  8.602879e-02
#
#               padj  category
# 25    1.746480e-12  Bergmann
# 6869           NaN       0.0

# %%
plt.scatter(df[df["category"] == cell_type1]["log2FoldChange"], -np.log10(df[df["category"] == cell_type1]["padj"]), label = cell_type1)
plt.scatter(df[df["category"] == cell_type2]["log2FoldChange"], -np.log10(df[df["category"] == cell_type2]["padj"]), label = cell_type2 )
plt.scatter(df[df["category"] == 0]["log2FoldChange"], -np.log10(df[df["category"] == 0]["padj"]), label = "non sig" )
plt.legend()

# %%
DE_genes = df[df["category"] != 0]
DE_genes
# Out:
#          gene    baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0     Fam107a  104.456630        7.208201  0.485089  14.859555  6.032473e-50
# 1     Septin4   85.370323        5.643409  0.396362  14.238036  5.320149e-46
# 2       Psg19  453.987662        2.610535  0.185950  14.038891  9.011221e-45
# 3         Id4   56.763669        6.338308  0.522475  12.131312  7.208539e-34
# 4          Qk   57.442895        5.677895  0.485392  11.697539  1.312042e-31
# ..        ...         ...             ...       ...        ...           ...
# 177     Traf4    9.104378        3.197841  1.000233   3.197096  1.388188e-03
# 178  Arhgap44    8.194360       -5.452027  1.711508  -3.185512  1.444983e-03
# 179    Ergic1   19.284781       -2.728129  0.858406  -3.178133  1.482268e-03
# 180    Frmpd1    4.284401        4.776915  1.502470   3.179375  1.475932e-03
# 181     Panx2    8.686743       -5.230540  1.645293  -3.179093  1.477369e-03
#
#              padj  category
# 0    7.172611e-47  Bergmann
# 1    3.162829e-43  Bergmann
# 2    3.571447e-42  Bergmann
# 3    2.142738e-31  Bergmann
# 4    3.120035e-29  Bergmann
# ..            ...       ...
# 177  9.272786e-03  Bergmann
# 178  9.598241e-03   Granule
# 179  9.683608e-03   Granule
# 180  9.683608e-03  Bergmann
# 181  9.683608e-03   Granule
#
# [179 rows x 8 columns]

# %% [markdown]
# # Map back to genome

# %%
meta = pd.read_csv(os.path.join("../annot", "Final", "mm10_25kb_bins_genes_09022022.csv"))
meta = meta[["name", "chrom", "start", "end", "gene", "100kb name", "100kb bin", "200kb name", "200kb bin"]]
meta["gene"] = meta["gene"].str.replace("-", ".")
meta["gene"] = meta["gene"].str.replace("March", "Marchf")
meta["gene"] = meta["gene"].str.replace("Sept", "Septin")

# %% [markdown]
# # Mismatch between DE gene naming and annotated namming

# %%
DE_sig_25kb = meta.merge(DE_genes)

# %%
# missing genes
miss_genes = [x for x in DE_genes["gene"]  if x not in DE_sig_25kb["gene"].unique()]
print ("missing {} gene, {} of detected DE genes".format(len(miss_genes), len(miss_genes) / DE_genes.shape[0]) )

# missing gene are not trivial
miss_df = df[df["gene"].isin(miss_genes)]
miss_df
# Out:
# missing 3 gene, 0.01675977653631285 of detected DE genes
#                gene   baseMean  log2FoldChange     lfcSE      stat  \
# 56   X9330188P03Rik  12.462777        4.896366  0.888942  5.508081
# 97   X2610035D17Rik  10.438414        4.017539  0.907684  4.426142
# 164  X2310022B05Rik   6.613218        4.376542  1.312087  3.335559
#
#            pvalue          padj  category
# 56   3.627656e-08  7.567164e-07  Bergmann
# 97   9.593348e-06  1.163928e-04  Bergmann
# 164  8.512824e-04  6.134393e-03  Bergmann

# %% [markdown]
# # OK! tried our best to get all genes

# %%
DE_sig_25kb["200kb bin"] = DE_sig_25kb["start"] // 200000
DE_sig_25kb["200kb name"] = DE_sig_25kb["chrom"] + "-g" + DE_sig_25kb["200kb bin"].astype(str)

# %%
cols = ["200kb name","chrom", "200kb bin", "gene", "baseMean", "log2FoldChange", "pvalue", "padj", "category"]

# %%
DE_sig_200kb = DE_sig_25kb.copy()
# Get DE norm counts
# Do not repeat count version
DE_sig_200kb_no_dup = DE_sig_200kb.drop_duplicates(subset=["gene", "200kb name"], keep='first')
DE_sig_200kb_no_dup
# Out:
#             name  chrom     start       end    gene  100kb name  100kb bin  \
# 0       chr1-772   chr1  22275000  22300000   Rims1   chr1-g222      222.0
# 5       chr1-777   chr1  22400000  22425000   Rims1   chr1-g224      224.0
# 13      chr1-785   chr1  22600000  22625000   Rims1   chr1-g226      226.0
# 21      chr1-793   chr1  22800000  22825000   Rims1   chr1-g228      228.0
# 22     chr1-2889   chr1  75225000  75250000   Ptprn   chr1-g752      752.0
# ...          ...    ...       ...       ...     ...         ...        ...
# 1280  chr19-1648  chr19  44275000  44300000    Scd2  chr19-g442      442.0
# 1282  chr19-2018  chr19  53525000  53550000   Dusp5  chr19-g535      535.0
# 1283    chrX-170   chrX   7625000   7650000     Syp    chrX-g76       76.0
# 1285   chrX-1246   chrX  35875000  35900000  Dock11   chrX-g358      358.0
# 1290   chrX-1251   chrX  36000000  36025000  Dock11   chrX-g360      360.0
#
#       200kb name  200kb bin   baseMean  log2FoldChange     lfcSE      stat  \
# 0      chr1-g111        111  39.683681       -3.843412  0.610434 -6.296199
# 5      chr1-g112        112  39.683681       -3.843412  0.610434 -6.296199
# 13     chr1-g113        113  39.683681       -3.843412  0.610434 -6.296199
# 21     chr1-g114        114  39.683681       -3.843412  0.610434 -6.296199
# 22     chr1-g376        376  13.615277       -3.620657  1.107387 -3.269549
# ...          ...        ...        ...             ...       ...       ...
# 1280  chr19-g221        221   7.130181        4.507579  1.210778  3.722878
# 1282  chr19-g267        267  28.622578       -3.568695  0.753533 -4.735954
# 1283    chrX-g38         38  27.606639       -3.369700  0.738793 -4.561089
# 1285   chrX-g179        179   5.896660        7.220815  1.792146  4.029144
# 1290   chrX-g180        180   5.896660        7.220815  1.792146  4.029144
#
#             pvalue          padj  category
# 0     3.050323e-10  9.544300e-09   Granule
# 5     3.050323e-10  9.544300e-09   Granule
# 13    3.050323e-10  9.544300e-09   Granule
# 21    3.050323e-10  9.544300e-09   Granule
# 22    1.077191e-03  7.578580e-03   Granule
# ...            ...           ...       ...
# 1280  1.969649e-04  1.787720e-03  Bergmann
# 1282  2.180274e-06  3.240432e-05   Granule
# 1283  5.088891e-06  7.024825e-05   Granule
# 1285  5.598031e-05  5.942909e-04  Bergmann
# 1290  5.598031e-05  5.942909e-04  Bergmann
#
# [315 rows x 16 columns]

# %%
# get norm counts
norm_counts = pd.read_csv(os.path.join(data_path, "ensembl_gene_counts_normalized.txt"), sep = "\t")

idx = (norm_counts.iloc[0].isin([cell_type1 ,cell_type2, "CLUSTER"])).values

norm_counts = norm_counts.iloc[:, idx]

# take a look
norm_counts.head()
# Out:
#                ID         1                 2                1.1  \
# 0         CLUSTER  Bergmann          Bergmann            Granule
# 1  X0610005C13Rik         0  1.28156580039671  0.360020332406605
# 2  X0610009B22Rik         0                 0                  0
# 3  X0610009L18Rik         0                 0   1.44008132962642
# 4  X0610010F05Rik         0                 0   2.88016265925284
#
#                  2.1
# 0            Granule
# 1  0.695614535929326
# 2  0.463743023952884
# 3   2.78245814371731
# 4   1.62310058383509

# %%
n1 = ["{}_{}".format(cell_type1, i) for i in range(1, 3)]
n2 = ["{}_{}".format(cell_type2, i) for i in range(1, 3)]

norm_counts.columns = ['gene'] + n1 + n2
norm_counts = norm_counts.iloc[1:].reset_index(drop = True)
norm_counts.head()
# turn dataframes to numeric
norm_counts[n1 + n2] = norm_counts[n1 + n2].apply(pd.to_numeric, errors='coerce')
norm_counts.head()
# Out:
#              gene  Bergmann_1  Bergmann_2  Granule_1  Granule_2
# 0  X0610005C13Rik         0.0    1.281566   0.360020   0.695615
# 1  X0610009B22Rik         0.0    0.000000   0.000000   0.463743
# 2  X0610009L18Rik         0.0    0.000000   1.440081   2.782458
# 3  X0610010F05Rik         0.0    0.000000   2.880163   1.623101
# 4  X0610040B10Rik         0.0    0.000000   0.000000   0.927486

# %%
norm_counts["{}_mean".format(cell_type1)] = norm_counts[n1].mean(axis=1)
norm_counts["{}_mean".format(cell_type2)] = norm_counts[n2].mean(axis=1)
norm_counts
# Out:
#                  gene  Bergmann_1  Bergmann_2  Granule_1  Granule_2  \
# 0      X0610005C13Rik    0.000000    1.281566   0.360020   0.695615
# 1      X0610009B22Rik    0.000000    0.000000   0.000000   0.463743
# 2      X0610009L18Rik    0.000000    0.000000   1.440081   2.782458
# 3      X0610010F05Rik    0.000000    0.000000   2.880163   1.623101
# 4      X0610040B10Rik    0.000000    0.000000   0.000000   0.927486
# ...               ...         ...         ...        ...        ...
# 17168             Zyx    3.722419    0.000000   5.040285   3.709944
# 17169           Zzef1    0.000000    0.000000   0.000000   0.695615
# 17170            Zzz3    1.861210    3.844697   2.880163   4.405559
# 17171               a    0.000000    0.000000   0.000000   0.000000
# 17172         ccdc198    0.000000    0.000000   0.000000   0.231872
#
#        Bergmann_mean  Granule_mean
# 0           0.640783      0.527817
# 1           0.000000      0.231872
# 2           0.000000      2.111270
# 3           0.000000      2.251632
# 4           0.000000      0.463743
# ...              ...           ...
# 17168       1.861210      4.375114
# 17169       0.000000      0.347807
# 17170       2.852954      3.642861
# 17171       0.000000      0.000000
# 17172       0.000000      0.115936
#
# [17173 rows x 7 columns]

# %%
# filter out DE genes get norm counts
DE_sig_200kb_no_dup = DE_sig_200kb_no_dup.merge(norm_counts[["gene","{}_mean".format(cell_type1), "{}_mean".format(cell_type2)]])
DE_sig_200kb_no_dup.to_csv(os.path.join(data_path, 
                                        "{}_{}_DE_sig_sum_200kb_no_dup.csv".format(cell_type1, cell_type2))
                           , index = False)

# %%
DE_sig_200kb_no_dup
# Out:
#            name  chrom     start       end    gene  100kb name  100kb bin  \
# 0      chr1-772   chr1  22275000  22300000   Rims1   chr1-g222      222.0
# 1      chr1-777   chr1  22400000  22425000   Rims1   chr1-g224      224.0
# 2      chr1-785   chr1  22600000  22625000   Rims1   chr1-g226      226.0
# 3      chr1-793   chr1  22800000  22825000   Rims1   chr1-g228      228.0
# 4     chr1-2889   chr1  75225000  75250000   Ptprn   chr1-g752      752.0
# ..          ...    ...       ...       ...     ...         ...        ...
# 310  chr19-1648  chr19  44275000  44300000    Scd2  chr19-g442      442.0
# 311  chr19-2018  chr19  53525000  53550000   Dusp5  chr19-g535      535.0
# 312    chrX-170   chrX   7625000   7650000     Syp    chrX-g76       76.0
# 313   chrX-1246   chrX  35875000  35900000  Dock11   chrX-g358      358.0
# 314   chrX-1251   chrX  36000000  36025000  Dock11   chrX-g360      360.0
#
#      200kb name  200kb bin   baseMean  log2FoldChange     lfcSE      stat  \
# 0     chr1-g111        111  39.683681       -3.843412  0.610434 -6.296199
# 1     chr1-g112        112  39.683681       -3.843412  0.610434 -6.296199
# 2     chr1-g113        113  39.683681       -3.843412  0.610434 -6.296199
# 3     chr1-g114        114  39.683681       -3.843412  0.610434 -6.296199
# 4     chr1-g376        376  13.615277       -3.620657  1.107387 -3.269549
# ..          ...        ...        ...             ...       ...       ...
# 310  chr19-g221        221   7.130181        4.507579  1.210778  3.722878
# 311  chr19-g267        267  28.622578       -3.568695  0.753533 -4.735954
# 312    chrX-g38         38  27.606639       -3.369700  0.738793 -4.561089
# 313   chrX-g179        179   5.896660        7.220815  1.792146  4.029144
# 314   chrX-g180        180   5.896660        7.220815  1.792146  4.029144
#
#            pvalue          padj  category  Bergmann_mean  Granule_mean
# 0    3.050323e-10  9.544300e-09   Granule       9.489466    139.466110
# 1    3.050323e-10  9.544300e-09   Granule       9.489466    139.466110
# 2    3.050323e-10  9.544300e-09   Granule       9.489466    139.466110
# 3    3.050323e-10  9.544300e-09   Granule       9.489466    139.466110
# 4    1.077191e-03  7.578580e-03   Granule       2.212171     27.763870
# ..            ...           ...       ...            ...           ...
# 310  1.969649e-04  1.787720e-03  Bergmann      23.464411      0.991560
# 311  2.180274e-06  3.240432e-05   Granule       7.979217    101.334929
# 312  5.088891e-06  7.024825e-05   Granule       5.065124     54.243418
# 313  5.598031e-05  5.942909e-04  Bergmann      22.060568      0.180010
# 314  5.598031e-05  5.942909e-04  Bergmann      22.060568      0.180010
#
# [315 rows x 18 columns]

# %%
temp = {"category" : ",".join, 
        "{}_mean".format(cell_type1) : sum,
        "{}_mean".format(cell_type2) : sum,
        "gene": ",".join}
final_200kb = DE_sig_200kb_no_dup.groupby("200kb name").agg(temp).reset_index()

# %%
final_200kb
# Out:
#     200kb name  category  Bergmann_mean  Granule_mean    gene
# 0    chr1-g111   Granule       9.489466    139.466110   Rims1
# 1    chr1-g112   Granule       9.489466    139.466110   Rims1
# 2    chr1-g113   Granule       9.489466    139.466110   Rims1
# 3    chr1-g114   Granule       9.489466    139.466110   Rims1
# 4    chr1-g376   Granule       2.212171     27.763870   Ptprn
# ..         ...       ...            ...           ...     ...
# 306  chr9-g346  Bergmann      32.709321      5.046303    Rora
# 307  chr9-g540   Granule       7.567117     87.624066     Bsn
# 308  chrX-g179  Bergmann      22.060568      0.180010  Dock11
# 309  chrX-g180  Bergmann      22.060568      0.180010  Dock11
# 310   chrX-g38   Granule       5.065124     54.243418     Syp
#
# [311 rows x 5 columns]

# %%
# further format
final_200kb["chrom"]  = final_200kb["200kb name"].str.split("-").str[0]
# add small number to 0
final_200kb = final_200kb.replace(0, 0.05)
final_200kb
# Out:
#     200kb name  category  Bergmann_mean  Granule_mean    gene chrom
# 0    chr1-g111   Granule       9.489466    139.466110   Rims1  chr1
# 1    chr1-g112   Granule       9.489466    139.466110   Rims1  chr1
# 2    chr1-g113   Granule       9.489466    139.466110   Rims1  chr1
# 3    chr1-g114   Granule       9.489466    139.466110   Rims1  chr1
# 4    chr1-g376   Granule       2.212171     27.763870   Ptprn  chr1
# ..         ...       ...            ...           ...     ...   ...
# 306  chr9-g346  Bergmann      32.709321      5.046303    Rora  chr9
# 307  chr9-g540   Granule       7.567117     87.624066     Bsn  chr9
# 308  chrX-g179  Bergmann      22.060568      0.180010  Dock11  chrX
# 309  chrX-g180  Bergmann      22.060568      0.180010  Dock11  chrX
# 310   chrX-g38   Granule       5.065124     54.243418     Syp  chrX
#
# [311 rows x 6 columns]

# %%
# rank final output
final_200kb["chrom_id"] = final_200kb["chrom"].str[3:].replace("X", 20).astype(int)
final_200kb["group"] = final_200kb["200kb name"].str.split("-").str[1].str[1:].astype(int)
final_200kb = final_200kb.sort_values(by = ["chrom_id", "group"])
final_200kb["log2FC_{}2{}".format(cell_type1[:1], cell_type2[:1])] =  np.log2(final_200kb["{}_mean".format(cell_type1)].values / final_200kb["{}_mean".format(cell_type2)].values)
final_200kb
# Out:
#      200kb name  category  Bergmann_mean  Granule_mean    gene  chrom  \
# 0     chr1-g111   Granule       9.489466    139.466110   Rims1   chr1
# 1     chr1-g112   Granule       9.489466    139.466110   Rims1   chr1
# 2     chr1-g113   Granule       9.489466    139.466110   Rims1   chr1
# 3     chr1-g114   Granule       9.489466    139.466110   Rims1   chr1
# 4     chr1-g376   Granule       2.212171     27.763870   Ptprn   chr1
# ..          ...       ...            ...           ...     ...    ...
# 148  chr19-g221  Bergmann      23.464411      0.991560    Scd2  chr19
# 149  chr19-g267   Granule       7.979217    101.334929   Dusp5  chr19
# 310    chrX-g38   Granule       5.065124     54.243418     Syp   chrX
# 308   chrX-g179  Bergmann      22.060568      0.180010  Dock11   chrX
# 309   chrX-g180  Bergmann      22.060568      0.180010  Dock11   chrX
#
#      chrom_id  group  log2FC_B2G
# 0           1    111   -3.877444
# 1           1    112   -3.877444
# 2           1    113   -3.877444
# 3           1    114   -3.877444
# 4           1    376   -3.649674
# ..        ...    ...         ...
# 148        19    221    4.564630
# 149        19    267   -3.666741
# 310        20     38   -3.420779
# 308        20    179    6.937248
# 309        20    180    6.937248
#
# [311 rows x 9 columns]

# %%
final_200kb.to_csv(os.path.join(data_path, "{}_{}_DE_200kb_FoldChange.csv".format(cell_type1, cell_type2)), index = False)
